# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
# added these dependencies
import json
import scipy.stats as st
from pprint import pprint
#this was already here
from scipy.stats import linregress


# Import API key after I placed the api keys file into the weather folder
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 612

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
city_weather = []

print ("Beginning Data Retrieval")
print("--------------------------")

rcd = 0
sets = 1
for city in cities:
    rcd += 1
  
    print(f'Processing Record {rcd} of Set {sets} | {city}')
    
    if rcd == 50:
        sets += 1
        rcd = 0
    
    try:
        url = f'https://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}&units=imperial'
        response = requests.get(url).json()
        city_weather.append({
            'city':city,
            'lat': response['coord']['lat'],
            'lon': response['coord']['lon'],
            'temp': response['main']['temp_max'],
            'humidity': response['main']['humidity'],
            'wind': response['wind']['speed'],
            'cloud': response['clouds']['all'],
            'country': response['sys']['country'],
            'date': response['dt']
        })
    except:
        print('City not found. Skipping...')
        pass                        
    
print('-----------------------------\nData Retrieval Complete\n-----------------------------')
# Out:
# Beginning Data Retrieval
# --------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | dikson
# Processing Record 3 of Set 1 | taltal
# Processing Record 4 of Set 1 | avarua
# Processing Record 5 of Set 1 | carauari
# Processing Record 6 of Set 1 | dapdap
# Processing Record 7 of Set 1 | torbay
# Processing Record 8 of Set 1 | trelew
# Processing Record 9 of Set 1 | cabedelo
# Processing Record 10 of Set 1 | otta
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | saldanha
# Processing Record 13 of Set 1 | ostrovnoy
# Processing Record 14 of Set 1 | touros
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | tombouctou
# Processing Record 17 of Set 1 | hermanus
# Processing Record 18 of Set 1 | esperance
# Processing Record 19 of Set 1 | cape town
# Processing Record 20 of Set 1 | butaritari
# Processing Record 21 of Set 1 | xuddur
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | sukhobezvodnoye
# Processing Record 24 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 1 | nikolskoye
# Processing Record 27 of Set 1 | tual
# Processing Record 28 of Set 1 | bubaque
# Processing Record 29 of Set 1 | betsiamites
# Processing Record 30 of Set 1 | linkoping
# Processing Record 31 of Set 1 | busselton
# Processing Record 32 of Set 1 | warrnambool
# Processing Record 33 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 1 | lorengau
# Processing Record 35 of Set 1 | kahului
# Processing Record 36 of Set 1 | perbaungan
# Processing Record 37 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 1 | bredasdorp
# Processing Record 39 of Set 1 | krasnyy yar
# Processing Record 40 of Set 1 | moyale
# Processing Record 41 of Set 1 | prainha
# Processing Record 42 of Set 1 | saint-georges
# Processing Record 43 of Set 1 | ascension
# Processing Record 44 of Set 1 | port alfred
# Processing Record 45 of Set 1 | diego de almagro
# Processing Record 46 of Set 1 | luderitz
# Processing Record 47 of Set 1 | broome
# Processing Record 48 of Set 1 | leningradskiy
# Processing Record 49 of Set 1 | norman wells
# Processing Record 50 of Set 1 | baykit
# Processing Record 1 of Set 2 | takoradi
# Processing Record 2 of Set 2 | namibe
# Processing Record 3 of Set 2 | tari
# Processing Record 4 of Set 2 | bluff
# Processing Record 5 of Set 2 | mitu
# Processing Record 6 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 2 | nelspruit
# Processing Record 8 of Set 2 | hambantota
# Processing Record 9 of Set 2 | balinsasayao
# Processing Record 10 of Set 2 | sandakan
# Processing Record 11 of Set 2 | constitucion
# Processing Record 12 of Set 2 | besenyszog
# Processing Record 13 of Set 2 | jamestown
# Processing Record 14 of Set 2 | mar del plata
# Processing Record 15 of Set 2 | atuona
# Processing Record 16 of Set 2 | colquechaca
# Processing Record 17 of Set 2 | tiksi
# Processing Record 18 of Set 2 | marovoay
# Processing Record 19 of Set 2 | hobart
# Processing Record 20 of Set 2 | uhlove
# Processing Record 21 of Set 2 | bethel
# Processing Record 22 of Set 2 | dibrugarh
# Processing Record 23 of Set 2 | khatanga
# Processing Record 24 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 2 | bara
# Processing Record 26 of Set 2 | nara
# Processing Record 27 of Set 2 | saskylakh
# Processing Record 28 of Set 2 | faanui
# Processing Record 29 of Set 2 | geraldton
# Processing Record 30 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 2 | nemuro
# Processing Record 32 of Set 2 | phan rang
# City not found. Skipping...
# Processing Record 33 of Set 2 | sur
# Processing Record 34 of Set 2 | san patricio
# Processing Record 35 of Set 2 | qaanaaq
# Processing Record 36 of Set 2 | yellowknife
# Processing Record 37 of Set 2 | luena
# Processing Record 38 of Set 2 | alice springs
# Processing Record 39 of Set 2 | lagoa
# Processing Record 40 of Set 2 | vestmannaeyjar
# Processing Record 41 of Set 2 | santa rosa
# Processing Record 42 of Set 2 | derzhavinsk
# Processing Record 43 of Set 2 | guarapari
# Processing Record 44 of Set 2 | ushuaia
# Processing Record 45 of Set 2 | kirando
# Processing Record 46 of Set 2 | puerto ayora
# Processing Record 47 of Set 2 | victoria
# Processing Record 48 of Set 2 | hay river
# Processing Record 49 of Set 2 | carnarvon
# Processing Record 50 of Set 2 | bafq
# Processing Record 1 of Set 3 | arraial do cabo
# Processing Record 2 of Set 3 | nouadhibou
# Processing Record 3 of Set 3 | east london
# Processing Record 4 of Set 3 | mokhsogollokh
# Processing Record 5 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 3 | yagoua
# Processing Record 7 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 3 | sorong
# Processing Record 9 of Set 3 | lompoc
# Processing Record 10 of Set 3 | lebu
# Processing Record 11 of Set 3 | cherskiy
# Processing Record 12 of Set 3 | troitsko-pechorsk
# Processing Record 13 of Set 3 | cayenne
# Processing Record 14 of Set 3 | biak
# Processing Record 15 of Set 3 | oyama
# Processing Record 16 of Set 3 | portland
# Processing Record 17 of Set 3 | abha
# Processing Record 18 of Set 3 | jumla
# Processing Record 19 of Set 3 | lohja
# Processing Record 20 of Set 3 | mirabad
# Processing Record 21 of Set 3 | chicama
# Processing Record 22 of Set 3 | kruisfontein
# Processing Record 23 of Set 3 | luganville
# Processing Record 24 of Set 3 | lavrentiya
# Processing Record 25 of Set 3 | cidreira
# Processing Record 26 of Set 3 | ponta pora
# Processing Record 27 of Set 3 | pevek
# Processing Record 28 of Set 3 | kavieng
# Processing Record 29 of Set 3 | tasiilaq
# Processing Record 30 of Set 3 | agadez
# Processing Record 31 of Set 3 | senneterre
# Processing Record 32 of Set 3 | sao jose da coroa grande
# Processing Record 33 of Set 3 | shabo
# Processing Record 34 of Set 3 | kopyevo
# City not found. Skipping...
# Processing Record 35 of Set 3 | fortuna
# Processing Record 36 of Set 3 | barrow
# Processing Record 37 of Set 3 | kurilsk
# Processing Record 38 of Set 3 | albany
# Processing Record 39 of Set 3 | sitka
# Processing Record 40 of Set 3 | buraydah
# Processing Record 41 of Set 3 | hilo
# Processing Record 42 of Set 3 | sinnamary
# Processing Record 43 of Set 3 | port hardy
# Processing Record 44 of Set 3 | tuktoyaktuk
# Processing Record 45 of Set 3 | saint-philippe
# Processing Record 46 of Set 3 | isangel
# Processing Record 47 of Set 3 | newport
# Processing Record 48 of Set 3 | faxinal
# Processing Record 49 of Set 3 | kaitangata
# Processing Record 50 of Set 3 | jalu
# Processing Record 1 of Set 4 | phnum penh
# City not found. Skipping...
# Processing Record 2 of Set 4 | chuy
# Processing Record 3 of Set 4 | chai badan
# Processing Record 4 of Set 4 | bamboo
# Processing Record 5 of Set 4 | hithadhoo
# Processing Record 6 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 4 | tsiroanomandidy
# Processing Record 8 of Set 4 | ust-nera
# Processing Record 9 of Set 4 | tura
# Processing Record 10 of Set 4 | ormara
# Processing Record 11 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 4 | grindavik
# Processing Record 13 of Set 4 | fairbanks
# Processing Record 14 of Set 4 | thompson
# Processing Record 15 of Set 4 | labutta
# City not found. Skipping...
# Processing Record 16 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 4 | mangrol
# Processing Record 18 of Set 4 | longyearbyen
# Processing Record 19 of Set 4 | burnie
# Processing Record 20 of Set 4 | port blair
# Processing Record 21 of Set 4 | mahebourg
# Processing Record 22 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 4 | chom bung
# City not found. Skipping...
# Processing Record 24 of Set 4 | kapaa
# Processing Record 25 of Set 4 | shirvan
# Processing Record 26 of Set 4 | bombay
# Processing Record 27 of Set 4 | paamiut
# Processing Record 28 of Set 4 | grand gaube
# Processing Record 29 of Set 4 | barabai
# Processing Record 30 of Set 4 | uray
# Processing Record 31 of Set 4 | pangkalanbuun
# Processing Record 32 of Set 4 | hobyo
# Processing Record 33 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 34 of Set 4 | pangai
# Processing Record 35 of Set 4 | zyryanka
# Processing Record 36 of Set 4 | juneau
# Processing Record 37 of Set 4 | georgetown
# Processing Record 38 of Set 4 | hailar
# Processing Record 39 of Set 4 | gua musang
# Processing Record 40 of Set 4 | aklavik
# Processing Record 41 of Set 4 | belaya gora
# Processing Record 42 of Set 4 | horta
# Processing Record 43 of Set 4 | bengkulu
# Processing Record 44 of Set 4 | lasa
# Processing Record 45 of Set 4 | sant julia de loria
# Processing Record 46 of Set 4 | huarmey
# Processing Record 47 of Set 4 | bonavista
# Processing Record 48 of Set 4 | ancud
# Processing Record 49 of Set 4 | beringovskiy
# Processing Record 50 of Set 4 | airai
# Processing Record 1 of Set 5 | sao joao da barra
# Processing Record 2 of Set 5 | dingle
# Processing Record 3 of Set 5 | anloga
# Processing Record 4 of Set 5 | saint george
# Processing Record 5 of Set 5 | bathsheba
# Processing Record 6 of Set 5 | codrington
# Processing Record 7 of Set 5 | haines junction
# Processing Record 8 of Set 5 | kajaani
# Processing Record 9 of Set 5 | chokurdakh
# Processing Record 10 of Set 5 | taywarah
# Processing Record 11 of Set 5 | moron
# Processing Record 12 of Set 5 | saint anthony
# Processing Record 13 of Set 5 | muroto
# Processing Record 14 of Set 5 | rio gallegos
# Processing Record 15 of Set 5 | consolacion del sur
# Processing Record 16 of Set 5 | burns lake
# Processing Record 17 of Set 5 | qaqortoq
# Processing Record 18 of Set 5 | icononzo
# Processing Record 19 of Set 5 | bukama
# Processing Record 20 of Set 5 | hope
# Processing Record 21 of Set 5 | tabou
# Processing Record 22 of Set 5 | maralal
# Processing Record 23 of Set 5 | okha
# Processing Record 24 of Set 5 | peski
# Processing Record 25 of Set 5 | port elizabeth
# Processing Record 26 of Set 5 | mogadishu
# Processing Record 27 of Set 5 | kerema
# Processing Record 28 of Set 5 | taoudenni
# Processing Record 29 of Set 5 | hirosaki
# Processing Record 30 of Set 5 | ballina
# Processing Record 31 of Set 5 | ngudu
# Processing Record 32 of Set 5 | mount gambier
# Processing Record 33 of Set 5 | kodiak
# Processing Record 34 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 35 of Set 5 | cabo san lucas
# Processing Record 36 of Set 5 | sazonovo
# Processing Record 37 of Set 5 | sibolga
# Processing Record 38 of Set 5 | sembe
# Processing Record 39 of Set 5 | dankov
# Processing Record 40 of Set 5 | linxia
# Processing Record 41 of Set 5 | bairiki
# Processing Record 42 of Set 5 | belmonte
# Processing Record 43 of Set 5 | suba
# Processing Record 44 of Set 5 | iskateley
# Processing Record 45 of Set 5 | road town
# Processing Record 46 of Set 5 | mosetse
# Processing Record 47 of Set 5 | kasongo-lunda
# Processing Record 48 of Set 5 | sola
# Processing Record 49 of Set 5 | mafra
# Processing Record 50 of Set 5 | new norfolk
# Processing Record 1 of Set 6 | severo-kurilsk
# Processing Record 2 of Set 6 | adrar
# Processing Record 3 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 4 of Set 6 | milledgeville
# Processing Record 5 of Set 6 | ahipara
# Processing Record 6 of Set 6 | camacha
# Processing Record 7 of Set 6 | sabaudia
# Processing Record 8 of Set 6 | marsh harbour
# Processing Record 9 of Set 6 | sao filipe
# Processing Record 10 of Set 6 | eureka
# Processing Record 11 of Set 6 | puerto cabello
# Processing Record 12 of Set 6 | ati
# Processing Record 13 of Set 6 | upernavik
# Processing Record 14 of Set 6 | terney
# Processing Record 15 of Set 6 | copiapo
# Processing Record 16 of Set 6 | port lincoln
# Processing Record 17 of Set 6 | marawi
# Processing Record 18 of Set 6 | colesberg
# Processing Record 19 of Set 6 | riyadh
# Processing Record 20 of Set 6 | clarence town
# Processing Record 21 of Set 6 | hamilton
# Processing Record 22 of Set 6 | castro
# Processing Record 23 of Set 6 | shimoda
# Processing Record 24 of Set 6 | zhaotong
# Processing Record 25 of Set 6 | kegayli
# City not found. Skipping...
# Processing Record 26 of Set 6 | coquimbo
# Processing Record 27 of Set 6 | khasan
# Processing Record 28 of Set 6 | mao
# Processing Record 29 of Set 6 | provideniya
# Processing Record 30 of Set 6 | dzilam gonzalez
# Processing Record 31 of Set 6 | vila franca do campo
# Processing Record 32 of Set 6 | umm jarr
# City not found. Skipping...
# Processing Record 33 of Set 6 | dunedin
# Processing Record 34 of Set 6 | muroran
# Processing Record 35 of Set 6 | ladario
# Processing Record 36 of Set 6 | mandalgovi
# Processing Record 37 of Set 6 | poum
# Processing Record 38 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 6 | qandala
# Processing Record 40 of Set 6 | tuatapere
# Processing Record 41 of Set 6 | goteborg
# City not found. Skipping...
# Processing Record 42 of Set 6 | kavaratti
# Processing Record 43 of Set 6 | champerico
# Processing Record 44 of Set 6 | ponta do sol
# Processing Record 45 of Set 6 | guerrero negro
# Processing Record 46 of Set 6 | matadi
# Processing Record 47 of Set 6 | samarai
# Processing Record 48 of Set 6 | emerald
# Processing Record 49 of Set 6 | isoka
# Processing Record 50 of Set 6 | vao
# Processing Record 1 of Set 7 | kilis
# Processing Record 2 of Set 7 | kismayo
# Processing Record 3 of Set 7 | oeiras
# Processing Record 4 of Set 7 | kyabe
# Processing Record 5 of Set 7 | penzance
# Processing Record 6 of Set 7 | bambous virieux
# Processing Record 7 of Set 7 | eskil
# Processing Record 8 of Set 7 | atar
# Processing Record 9 of Set 7 | manokwari
# Processing Record 10 of Set 7 | muros
# Processing Record 11 of Set 7 | saint-augustin
# Processing Record 12 of Set 7 | avera
# Processing Record 13 of Set 7 | hualmay
# Processing Record 14 of Set 7 | hofn
# Processing Record 15 of Set 7 | brae
# Processing Record 16 of Set 7 | conceicao do araguaia
# Processing Record 17 of Set 7 | kashi
# Processing Record 18 of Set 7 | yeppoon
# Processing Record 19 of Set 7 | lucapa
# Processing Record 20 of Set 7 | urfa
# City not found. Skipping...
# Processing Record 21 of Set 7 | moulins
# Processing Record 22 of Set 7 | mount isa
# Processing Record 23 of Set 7 | mendahara
# City not found. Skipping...
# Processing Record 24 of Set 7 | vila velha
# Processing Record 25 of Set 7 | yatou
# Processing Record 26 of Set 7 | gurgan
# City not found. Skipping...
# Processing Record 27 of Set 7 | wawa
# Processing Record 28 of Set 7 | lokosovo
# Processing Record 29 of Set 7 | formosa
# Processing Record 30 of Set 7 | inirida
# Processing Record 31 of Set 7 | narsaq
# Processing Record 32 of Set 7 | sechura
# Processing Record 33 of Set 7 | iquique
# Processing Record 34 of Set 7 | emba
# Processing Record 35 of Set 7 | payo
# Processing Record 36 of Set 7 | pengcheng
# Processing Record 37 of Set 7 | ixtapa
# Processing Record 38 of Set 7 | shubarshi
# Processing Record 39 of Set 7 | nome
# Processing Record 40 of Set 7 | kijang
# Processing Record 41 of Set 7 | klaksvik
# Processing Record 42 of Set 7 | san jose
# Processing Record 43 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 44 of Set 7 | los llanos de aridane
# Processing Record 45 of Set 7 | sakakah
# Processing Record 46 of Set 7 | tayzhina
# Processing Record 47 of Set 7 | dire
# Processing Record 48 of Set 7 | camp verde
# Processing Record 49 of Set 7 | paka
# Processing Record 50 of Set 7 | baruun-urt
# Processing Record 1 of Set 8 | harper
# Processing Record 2 of Set 8 | salalah
# Processing Record 3 of Set 8 | poronaysk
# Processing Record 4 of Set 8 | blenheim
# Processing Record 5 of Set 8 | west richland
# Processing Record 6 of Set 8 | bida
# Processing Record 7 of Set 8 | kieta
# Processing Record 8 of Set 8 | cabinda
# Processing Record 9 of Set 8 | miri
# Processing Record 10 of Set 8 | kaoma
# Processing Record 11 of Set 8 | berlevag
# Processing Record 12 of Set 8 | ejido hermosillo
# Processing Record 13 of Set 8 | jizan
# Processing Record 14 of Set 8 | ponta delgada
# Processing Record 15 of Set 8 | iqaluit
# Processing Record 16 of Set 8 | snihurivka
# Processing Record 17 of Set 8 | santa cruz de la palma
# Processing Record 18 of Set 8 | piacabucu
# Processing Record 19 of Set 8 | griffith
# Processing Record 20 of Set 8 | yenagoa
# Processing Record 21 of Set 8 | kippen
# Processing Record 22 of Set 8 | sai buri
# Processing Record 23 of Set 8 | dom pedrito
# Processing Record 24 of Set 8 | grand-santi
# Processing Record 25 of Set 8 | shetpe
# Processing Record 26 of Set 8 | aksarka
# Processing Record 27 of Set 8 | nadym
# Processing Record 28 of Set 8 | pierre
# Processing Record 29 of Set 8 | acajutla
# Processing Record 30 of Set 8 | richards bay
# Processing Record 31 of Set 8 | samana
# Processing Record 32 of Set 8 | wanning
# Processing Record 33 of Set 8 | tessalit
# Processing Record 34 of Set 8 | tanabe
# Processing Record 35 of Set 8 | oriximina
# Processing Record 36 of Set 8 | neuquen
# Processing Record 37 of Set 8 | mnogovershinnyy
# Processing Record 38 of Set 8 | sauda
# Processing Record 39 of Set 8 | shelbyville
# Processing Record 40 of Set 8 | bantva
# Processing Record 41 of Set 8 | san pedro
# Processing Record 42 of Set 8 | agirish
# Processing Record 43 of Set 8 | thinadhoo
# Processing Record 44 of Set 8 | komsomolskiy
# Processing Record 45 of Set 8 | araouane
# Processing Record 46 of Set 8 | vardo
# Processing Record 47 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 48 of Set 8 | kazanskoye
# Processing Record 49 of Set 8 | maroantsetra
# Processing Record 50 of Set 8 | la ronge
# Processing Record 1 of Set 9 | dandong
# Processing Record 2 of Set 9 | pacific grove
# Processing Record 3 of Set 9 | korla
# Processing Record 4 of Set 9 | finspang
# Processing Record 5 of Set 9 | bozhou
# Processing Record 6 of Set 9 | ambilobe
# Processing Record 7 of Set 9 | linfen
# Processing Record 8 of Set 9 | port augusta
# Processing Record 9 of Set 9 | asau
# Processing Record 10 of Set 9 | margate
# Processing Record 11 of Set 9 | ohara
# Processing Record 12 of Set 9 | severo-yeniseyskiy
# Processing Record 13 of Set 9 | waingapu
# Processing Record 14 of Set 9 | pussi
# Processing Record 15 of Set 9 | tuggurt
# City not found. Skipping...
# Processing Record 16 of Set 9 | dekoa
# City not found. Skipping...
# Processing Record 17 of Set 9 | pitkyaranta
# Processing Record 18 of Set 9 | alakurtti
# Processing Record 19 of Set 9 | zhezkazgan
# Processing Record 20 of Set 9 | natitingou
# Processing Record 21 of Set 9 | pitimbu
# Processing Record 22 of Set 9 | lethem
# Processing Record 23 of Set 9 | pacifica
# Processing Record 24 of Set 9 | bandarbeyla
# Processing Record 25 of Set 9 | sao domingos
# Processing Record 26 of Set 9 | muisne
# Processing Record 27 of Set 9 | nikolsk
# Processing Record 28 of Set 9 | coevorden
# Processing Record 29 of Set 9 | nata
# Processing Record 30 of Set 9 | sanming
# Processing Record 31 of Set 9 | pangnirtung
# Processing Record 32 of Set 9 | pemangkat
# Processing Record 33 of Set 9 | balikpapan
# Processing Record 34 of Set 9 | san ignacio
# Processing Record 35 of Set 9 | mangulile
# Processing Record 36 of Set 9 | tokzar
# City not found. Skipping...
# Processing Record 37 of Set 9 | chuka
# Processing Record 38 of Set 9 | gwadar
# Processing Record 39 of Set 9 | pangody
# Processing Record 40 of Set 9 | najran
# Processing Record 41 of Set 9 | wattegama
# Processing Record 42 of Set 9 | rio grande
# Processing Record 43 of Set 9 | balakhta
# Processing Record 44 of Set 9 | roncesvalles
# Processing Record 45 of Set 9 | yarada
# Processing Record 46 of Set 9 | aykhal
# Processing Record 47 of Set 9 | gurupa
# Processing Record 48 of Set 9 | sahuaripa
# Processing Record 49 of Set 9 | nanortalik
# Processing Record 50 of Set 9 | vila do maio
# Processing Record 1 of Set 10 | muravlenko
# Processing Record 2 of Set 10 | dicabisagan
# Processing Record 3 of Set 10 | tonantins
# Processing Record 4 of Set 10 | skibbereen
# Processing Record 5 of Set 10 | pulandian
# Processing Record 6 of Set 10 | kampot
# Processing Record 7 of Set 10 | bullhead city
# Processing Record 8 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 9 of Set 10 | srednekolymsk
# Processing Record 10 of Set 10 | sabang
# Processing Record 11 of Set 10 | souillac
# Processing Record 12 of Set 10 | henties bay
# Processing Record 13 of Set 10 | mosquera
# Processing Record 14 of Set 10 | carnot
# Processing Record 15 of Set 10 | tazovskiy
# Processing Record 16 of Set 10 | nuuk
# Processing Record 17 of Set 10 | yar-sale
# Processing Record 18 of Set 10 | grants
# Processing Record 19 of Set 10 | college
# Processing Record 20 of Set 10 | winnemucca
# Processing Record 21 of Set 10 | rolim de moura
# City not found. Skipping...
# Processing Record 22 of Set 10 | mentok
# City not found. Skipping...
# Processing Record 23 of Set 10 | renukut
# Processing Record 24 of Set 10 | laguna
# Processing Record 25 of Set 10 | kidal
# Processing Record 26 of Set 10 | ilulissat
# Processing Record 27 of Set 10 | goshen
# Processing Record 28 of Set 10 | soyo
# Processing Record 29 of Set 10 | karratha
# Processing Record 30 of Set 10 | punta alta
# Processing Record 31 of Set 10 | makakilo city
# Processing Record 32 of Set 10 | maryville
# Processing Record 33 of Set 10 | andros town
# Processing Record 34 of Set 10 | ribeira grande
# Processing Record 35 of Set 10 | walvis bay
# Processing Record 36 of Set 10 | diebougou
# Processing Record 37 of Set 10 | yulara
# Processing Record 38 of Set 10 | poyarkovo
# Processing Record 39 of Set 10 | peceneaga
# Processing Record 40 of Set 10 | benguela
# Processing Record 41 of Set 10 | caravelas
# Processing Record 42 of Set 10 | arlit
# Processing Record 43 of Set 10 | manawar
# Processing Record 44 of Set 10 | mackay
# Processing Record 45 of Set 10 | sigli
# Processing Record 46 of Set 10 | zavetnoye
# Processing Record 47 of Set 10 | shingu
# Processing Record 48 of Set 10 | bratsk
# Processing Record 49 of Set 10 | flin flon
# Processing Record 50 of Set 10 | sorland
# Processing Record 1 of Set 11 | samfya
# Processing Record 2 of Set 11 | bud
# Processing Record 3 of Set 11 | verkhnyaya inta
# Processing Record 4 of Set 11 | bukachacha
# Processing Record 5 of Set 11 | nipawin
# Processing Record 6 of Set 11 | warrington
# Processing Record 7 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 11 | cullinan
# Processing Record 9 of Set 11 | lazaro cardenas
# Processing Record 10 of Set 11 | inuvik
# Processing Record 11 of Set 11 | xining
# Processing Record 12 of Set 11 | pemagatsel
# Processing Record 13 of Set 11 | guhagar
# Processing Record 14 of Set 11 | puerto quijarro
# Processing Record 15 of Set 11 | keningau
# Processing Record 16 of Set 11 | namatanai
# Processing Record 17 of Set 11 | acarau
# Processing Record 18 of Set 11 | broken hill
# Processing Record 19 of Set 11 | blantyre
# Processing Record 20 of Set 11 | kapuskasing
# Processing Record 21 of Set 11 | nhulunbuy
# Processing Record 22 of Set 11 | lubango
# Processing Record 23 of Set 11 | narasannapeta
# Processing Record 24 of Set 11 | wazzan
# City not found. Skipping...
# Processing Record 25 of Set 11 | umm lajj
# Processing Record 26 of Set 11 | rosa zarate
# Processing Record 27 of Set 11 | arumbavur
# Processing Record 28 of Set 11 | olutanga
# Processing Record 29 of Set 11 | parrita
# Processing Record 30 of Set 11 | ughelli
# Processing Record 31 of Set 11 | krefeld
# Processing Record 32 of Set 11 | bayeux
# Processing Record 33 of Set 11 | fakel
# Processing Record 34 of Set 11 | taburi
# City not found. Skipping...
# Processing Record 35 of Set 11 | mehamn
# Processing Record 36 of Set 11 | yaan
# Processing Record 37 of Set 11 | lundazi
# Processing Record 38 of Set 11 | kamen-rybolov
# Processing Record 39 of Set 11 | ulety
# Processing Record 40 of Set 11 | coihaique
# Processing Record 41 of Set 11 | asyut
# Processing Record 42 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 11 | yeletskiy
# City not found. Skipping...
# Processing Record 44 of Set 11 | tabory
# Processing Record 45 of Set 11 | high prairie
# Processing Record 46 of Set 11 | jennings
# Processing Record 47 of Set 11 | ruteng
# Processing Record 48 of Set 11 | ambulu
# Processing Record 49 of Set 11 | whitehorse
# Processing Record 50 of Set 11 | camocim
# Processing Record 1 of Set 12 | izhma
# Processing Record 2 of Set 12 | marfino
# Processing Record 3 of Set 12 | cagliari
# Processing Record 4 of Set 12 | okitipupa
# Processing Record 5 of Set 12 | tomatlan
# Processing Record 6 of Set 12 | sembakung
# Processing Record 7 of Set 12 | dennis
# Processing Record 8 of Set 12 | nibbar
# Processing Record 9 of Set 12 | malibu
# Processing Record 10 of Set 12 | anjiang
# Processing Record 11 of Set 12 | erenhot
# Processing Record 12 of Set 12 | coruripe
# Processing Record 13 of Set 12 | naze
# Processing Record 14 of Set 12 | padang
# Processing Record 15 of Set 12 | dudinka
# Processing Record 16 of Set 12 | krivosheino
# Processing Record 17 of Set 12 | flinders
# Processing Record 18 of Set 12 | praia da vitoria
# Processing Record 19 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 20 of Set 12 | rawson
# Processing Record 21 of Set 12 | opuwo
# Processing Record 22 of Set 12 | issenye
# Processing Record 23 of Set 12 | wailuku
# Processing Record 24 of Set 12 | chokwe
# Processing Record 25 of Set 12 | easley
# Processing Record 26 of Set 12 | san rafael
# Processing Record 27 of Set 12 | malwan
# City not found. Skipping...
# Processing Record 28 of Set 12 | cuauhtemoc
# Processing Record 29 of Set 12 | tautira
# Processing Record 30 of Set 12 | quatre cocos
# Processing Record 31 of Set 12 | nuevo laredo
# Processing Record 32 of Set 12 | hervey bay
# Processing Record 33 of Set 12 | espana
# Processing Record 34 of Set 12 | gubskaya
# Processing Record 35 of Set 12 | elk city
# Processing Record 36 of Set 12 | celestun
# Processing Record 37 of Set 12 | chapais
# Processing Record 38 of Set 12 | gilgit
# Processing Record 39 of Set 12 | killybegs
# Processing Record 40 of Set 12 | cozumel
# Processing Record 41 of Set 12 | meulaboh
# Processing Record 42 of Set 12 | ranong
# Processing Record 43 of Set 12 | kaeo
# Processing Record 44 of Set 12 | maceio
# Processing Record 45 of Set 12 | mattru
# Processing Record 46 of Set 12 | biltine
# Processing Record 47 of Set 12 | fereydun kenar
# Processing Record 48 of Set 12 | port-gentil
# Processing Record 49 of Set 12 | clyde river
# Processing Record 50 of Set 12 | urengoy
# Processing Record 1 of Set 13 | bondo
# Processing Record 2 of Set 13 | bassano
# Processing Record 3 of Set 13 | marzuq
# Processing Record 4 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 5 of Set 13 | magadan
# Processing Record 6 of Set 13 | yining
# Processing Record 7 of Set 13 | guane
# Processing Record 8 of Set 13 | panan
# Processing Record 9 of Set 13 | nantucket
# Processing Record 10 of Set 13 | dongsheng
# Processing Record 11 of Set 13 | kil
# Processing Record 12 of Set 13 | mbarara

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data = pd.DataFrame(city_weather)
city_data.head()
# Out:
#        city      lat       lon   temp  humidity   wind  cloud country  \
# 0   mataura -46.1927  168.8643  73.00        64   3.00     31      NZ
# 1    dikson  73.5069   80.5464 -28.86        80   5.48      0      RU
# 2    taltal -25.4000  -70.4833  67.24        65   6.11     36      CL
# 3    avarua -21.2078 -159.7750  86.00        66  17.27     40      CK
# 4  carauari  -4.8828  -66.8958  74.26        94   1.54     79      BR
#
#          date
# 0  1610665341
# 1  1610665543
# 2  1610665543
# 3  1610665543
# 4  1610665544

# %%
city_data.describe()
# Out:
#               lat         lon        temp   humidity        wind       cloud  \
# count  568.000000  568.000000  568.000000  568.00000  568.000000  568.000000
# mean    18.845972   17.660136   51.472007   74.15669    8.089190   53.885563
# std     32.533143   89.583318   31.466091   20.70593    5.759765   38.352021
# min    -54.800000 -175.200000  -49.880000   11.00000    0.270000    0.000000
# 25%     -6.279200  -59.586725   33.950000   67.00000    3.520000   16.000000
# 50%     19.841650   20.830700   64.400000   80.00000    6.780000   62.500000
# 75%     46.175525   98.670900   76.000000   88.00000   11.252500   90.000000
# max     78.218600  179.316700   94.600000  100.00000   39.120000  100.000000
#
#                date
# count  5.680000e+02
# mean   1.610666e+09
# std    6.773599e+01
# min    1.610665e+09
# 25%    1.610666e+09
# 50%    1.610666e+09
# 75%    1.610666e+09
# max    1.610666e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(city_data.lat, city_data.temp, edgecolors='black',alpha=.8)
plt.title(f'City Latitude vs. Max Temperature ({time.strftime("%x")})')
plt.grid(True)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
# Out:
# Text(0, 0.5, 'Max Temperature (F)')

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build the scatter plots for each city types
plt.scatter(city_data.lat, city_data.humidity, edgecolors='black',alpha=.8)
plt.title(f'City Latitude vs. Humidity ({time.strftime("%x")})')
plt.grid(True)
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")

plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build the scatter plots for each city types
plt.scatter(city_data.lat, city_data.cloud, edgecolors='black',alpha=.8)
plt.title(f'City Latitude vs. Cloudiness ({time.strftime("%x")})')
plt.grid(True)
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")

plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for each city types
plt.scatter(city_data.lat, city_data.wind, edgecolors='black',alpha=.8)
plt.title(f'City Latitude vs. Wind Speed ({time.strftime("%x")})')
plt.grid(True)
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")

plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.46937863826630627

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.6082708688906918

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.000543987878808455

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.014985174297345524

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0020898727664228514

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0035263772085582894

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.04019723576144484

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.017128274759839232

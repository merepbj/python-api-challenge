# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
# added these dependencies
import json
import scipy.stats as st
from pprint import pprint
#this was already here
from scipy.stats import linregress


# Import API key after I placed the api keys file into the weather folder
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 596

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
city_weather = []

print ("Beginning Data Retrieval")
print("--------------------------")

rcd = 0
sets = 1
for city in cities:
    rcd += 1
  
    print(f'Processing Record {rcd} of Set {sets} | {city}')
    
    if rcd == 50:
        sets += 1
        rcd = 0
    
    try:
        url = f'https://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}&units=imperial'
        response = requests.get(url).json()
        city_weather.append({
            'city':city,
            'lat': response['coord']['lat'],
            'lon': response['coord']['lon'],
            'temp': response['main']['temp_max'],
            'humidity': response['main']['humidity'],
            'wind': response['wind']['speed'],
            'cloud': response['clouds']['all'],
            'country': response['sys']['country'],
            'date': response['dt']
        })
    except:
       print('City not found. Skipping...')
       pass                        
    
print('-----------------------------\nData Retrieval Complete\n-----------------------------')
# Out:
# Beginning Data Retrieval
# --------------------------
# Processing Record 1 of Set 1 | poum
# Processing Record 2 of Set 1 | hilo
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | chongwe
# Processing Record 6 of Set 1 | new norfolk
# Processing Record 7 of Set 1 | hobart
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | ongole
# Processing Record 10 of Set 1 | hamilton
# Processing Record 11 of Set 1 | khatanga
# Processing Record 12 of Set 1 | esperance
# Processing Record 13 of Set 1 | young
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | arraial do cabo
# Processing Record 17 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 1 | ostrovnoy
# Processing Record 19 of Set 1 | atuona
# Processing Record 20 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 1 | lebu
# Processing Record 22 of Set 1 | nishihara
# Processing Record 23 of Set 1 | rorvik
# Processing Record 24 of Set 1 | airai
# Processing Record 25 of Set 1 | cape town
# Processing Record 26 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 1 | pisco
# Processing Record 28 of Set 1 | luderitz
# Processing Record 29 of Set 1 | mount isa
# Processing Record 30 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 1 | san patricio
# Processing Record 32 of Set 1 | mataura
# Processing Record 33 of Set 1 | charters towers
# Processing Record 34 of Set 1 | saint george
# Processing Record 35 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 1 | charleston
# Processing Record 37 of Set 1 | saint-philippe
# Processing Record 38 of Set 1 | saint-paul
# Processing Record 39 of Set 1 | chabahar
# Processing Record 40 of Set 1 | puerto ayora
# Processing Record 41 of Set 1 | punta arenas
# Processing Record 42 of Set 1 | ponta do sol
# Processing Record 43 of Set 1 | constitucion
# Processing Record 44 of Set 1 | vila velha
# Processing Record 45 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 1 | naze
# Processing Record 47 of Set 1 | chiang khong
# Processing Record 48 of Set 1 | souillac
# Processing Record 49 of Set 1 | karlovo
# Processing Record 50 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record
# Processing Record 46 of Set 4 | luziania
# Processing Record 47 of Set 4 | saryg-sep
# Processing Record 48 of Set 4 | norman wells
# Processing Record 49 of Set 4 | pauini
# Processing Record 50 of Set 4 | celestun
# Processing Record 1 of Set 5 | nyagan
# Processing Record 2 of Set 5 | santa maria del oro
# Processing Record 3 of Set 5 | necochea
# Processing Record 4 of Set 5 | narsaq
# Processing Record 5 of Set 5 | tigil
# Processing Record 6 of Set 5 | nanortalik
# Processing Record 7 of Set 5 | muisne
# Processing Record 8 of Set 5 | ancud
# Processing Record 9 of Set 5 | wuwei
# Processing Record 10 of Set 5 | mirnyy
# Processing Record 11 of Set 5 | adre
# Processing Record 12 of Set 5 | sao filipe
# Processing Record 13 of Set 5 | the valley
# Processing Record 14 of Set 5 | maldonado
# Processing Record 15 of Set 5 | moorhead
# Processing Record 16 of Set 5 | ambulu
# Processing Record 17 of Set 5 | nouadhibou
# Processing Record 18 of Set 5 | bogovarovo
# Processing Record 19 of Set 5 | lagoa
# Processing Record 20 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 21 of Set 5 | luanda
# Processing Record 22 of Set 5 | coquimbo
# Processing Record 23 of Set 5 | muriti
# Processing Record 24 of Set 5 | ikwiriri
# Processing Record 25 of Set 5 | tautira
# Processing Record 26 of Set 5 | angoche
# Processing Record 27 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 5 | bathsheba
# Processing Record 29 of Set 5 | coronini
# Processing Record 30 of Set 5 | kargasok
# Processing Record 31 of Set 5 | honiara
# Processing Record 32 of Set 5 | moindou
# Processing Record 33 of Set 5 | barrow
# Processing Record 34 of Set 5 | sopetran
# Processing Record 35 of Set 5 | morwell
# Processing Record 36 of Set 5 | jevargi
# Processing Record 37 of Set 5 | kastamonu
# Processing Record 38 of Set 5 | mlonggo
# Processing Record 39 of Set 5 | castro
# Processing Record 40 of Set 5 | hay river
# Processing Record 41 of Set 5 | myitkyina
# Processing Record 42 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 43 of Set 5 | vanimo
# Processing Record 44 of Set 5 | avarua
# Processing Record 45 of Set 5 | port augusta
# Processing Record 46 of Set 5 | husavik
# Processing Record 47 of Set 5 | thompson
# Processing Record 48 of Set 5 | emerald
# Processing Record 49 of Set 5 | cabo san lucas
# Processing Record 50 of Set 5 | lompoc
# Processing Record 1 of Set 6 | pacific grove
# Processing Record 2 of Set 6 | denpasar
# Processing Record 3 of Set 6 | show low
# Processing Record 4 of Set 6 | nelson bay
# Processing Record 5 of Set 6 | budogoshch
# Processing Record 6 of Set 6 | port blair
# Processing Record 7 of Set 6 | acapulco
# Processing Record 8 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 6 | port macquarie
# Processing Record 10 of Set 6 | progreso
# Processing Record 11 of Set 6 | morro bay
# Processing Record 12 of Set 6 | akersberga
# Processing Record 13 of Set 6 | tubruq
# City not found. Skipping...
# Processing Record 14 of Set 6 | zatoka
# Processing Record 15 of Set 6 | zhangjiakou
# Processing Record 16 of Set 6 | vikhorevka
# Processing Record 17 of Set 6 | lagoa nova
# Processing Record 18 of Set 6 | trat
# Processing Record 19 of Set 6 | fairbanks
# Processing Record 20 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 6 | najran
# Processing Record 22 of Set 6 | nome
# Processing Record 23 of Set 6 | qaqortoq
# Processing Record 24 of Set 6 | fortuna
# Processing Record 25 of Set 6 | komsomolskiy
# Processing Record 26 of Set 6 | port hedland
# Processing Record 27 of Set 6 | hereford
# Processing Record 28 of Set 6 | malinovskiy
# Processing Record 29 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 30 of Set 6 | provideniya
# Processing Record 31 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 6 | biak
# Processing Record 33 of Set 6 | lebedyn
# Processing Record 34 of Set 6 | grindavik
# Processing Record 35 of Set 6 | bethel
# Processing Record 36 of Set 6 | kieta
# Processing Record 37 of Set 6 | siderno
# Processing Record 38 of Set 6 | tarauaca
# Processing Record 39 of Set 6 | taunggyi
# Processing Record 40 of Set 6 | guerrero negro
# Processing Record 41 of Set 6 | tooele
# Processing Record 42 of Set 6 | lawton
# Processing Record 43 of Set 6 | hualmay
# Processing Record 44 of Set 6 | walvis bay
# Processing Record 45 of Set 6 | natal
# Processing Record 46 of Set 6 | vila do maio
# Processing Record 47 of Set 6 | newport
# Processing Record 48 of Set 6 | mayo
# Processing Record 49 of Set 6 | pitimbu
# Processing Record 50 of Set 6 | yurga
# Processing Record 1 of Set 7 | acarau
# Processing Record 2 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 3 of Set 7 | yerbogachen
# Processing Record 4 of Set 7 | kropotkin
# Processing Record 5 of Set 7 | puerto el triunfo
# Processing Record 6 of Set 7 | trairi
# Processing Record 7 of Set 7 | kayerkan
# Processing Record 8 of Set 7 | welver
# Processing Record 9 of Set 7 | takehara
# Processing Record 10 of Set 7 | tromso
# Processing Record 11 of Set 7 | kavieng
# Processing Record 12 of Set 7 | champerico
# Processing Record 13 of Set 7 | palana
# Processing Record 14 of Set 7 | charsadda
# Processing Record 15 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 16 of Set 7 | merrill
# Processing Record 17 of Set 7 | morant bay
# Processing Record 18 of Set 7 | kununurra
# Processing Record 19 of Set 7 | butembo
# Processing Record 20 of Set 7 | tatawin
# Processing Record 21 of Set 7 | buckeye
# Processing Record 22 of Set 7 | parrita
# Processing Record 23 of Set 7 | virginia beach
# Processing Record 24 of Set 7 | elat
# Processing Record 25 of Set 7 | el campo
# Processing Record 26 of Set 7 | villa carlos paz
# Processing Record 27 of Set 7 | diamantino
# Processing Record 28 of Set 7 | cidreira
# Processing Record 29 of Set 7 | ngunguru
# Processing Record 30 of Set 7 | marsa matruh
# Processing Record 31 of Set 7 | tiksi
# Processing Record 32 of Set 7 | leningradskiy
# Processing Record 33 of Set 7 | worthing
# Processing Record 34 of Set 7 | vestmannaeyjar
# Processing Record 35 of Set 7 | balkhash
# Processing Record 36 of Set 7 | dunedin
# Processing Record 37 of Set 7 | anadyr
# Processing Record 38 of Set 7 | velingara
# Processing Record 5 of Set 9 | muskogee
# Processing Record 6 of Set 9 | namibe
# Processing Record 7 of Set 9 | litayen
# City not found. Skipping...
# Processing Record 8 of Set 9 | shanhetun
# Processing Record 9 of Set 9 | thunder bay
# Processing Record 10 of Set 9 | westport
# Processing Record 11 of Set 9 | torbay
# Processing Record 12 of Set 9 | hosanagara
# Processing Record 13 of Set 9 | pochutla
# Processing Record 14 of Set 9 | monroe
# Processing Record 15 of Set 9 | kalmunai
# Processing Record 16 of Set 9 | qandala
# Processing Record 17 of Set 9 | bururi
# Processing Record 18 of Set 9 | ketchikan
# Processing Record 19 of Set 9 | zhanakorgan
# Processing Record 20 of Set 9 | korla
# Processing Record 21 of Set 9 | rio grande
# Processing Record 22 of Set 9 | ciudad bolivar
# Processing Record 23 of Set 9 | pangobilian
# Processing Record 24 of Set 9 | uvinza
# Processing Record 25 of Set 9 | camana
# Processing Record 26 of Set 9 | saint-joseph
# Processing Record 27 of Set 9 | beberibe
# Processing Record 28 of Set 9 | bourail
# Processing Record 29 of Set 9 | vardo
# Processing Record 30 of Set 9 | tabarqah
# City not found. Skipping...
# Processing Record 31 of Set 9 | vila franca do campo
# Processing Record 32 of Set 9 | geraldton
# Processing Record 33 of Set 9 | havre-saint-pierre
# Processing Record 34 of Set 9 | mbanza-ngungu
# Processing Record 35 of Set 9 | saint-pierre
# Processing Record 36 of Set 9 | asau
# Processing Record 37 of Set 9 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 38 of Set 9 | sinkat
# City not found. Skipping...
# Processing Record 39 of Set 9 | maceio
# Processing Record 40 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 41 of Set 9 | freeport
# Processing Record 42 of Set 9 | kurilsk
# Processing Record 43 of Set 9 | adrar
# Processing Record 44 of Set 9 | humaita
# Processing Record 45 of Set 9 | huarmey
# Processing Record 46 of Set 9 | college
# Processing Record 47 of Set 9 | aljezur
# Processing Record 48 of Set 9 | pemberton
# Processing Record 49 of Set 9 | santa rosa
# Processing Record 50 of Set 9 | saint anthony
# Processing Record 1 of Set 10 | balsas
# Processing Record 2 of Set 10 | gazojak
# Processing Record 3 of Set 10 | eydhafushi
# Processing Record 4 of Set 10 | seoul
# Processing Record 5 of Set 10 | broome
# Processing Record 6 of Set 10 | oulainen
# Processing Record 7 of Set 10 | ariquemes
# Processing Record 8 of Set 10 | mutsamudu
# City not found. Skipping...
# Processing Record 9 of Set 10 | maragogi
# Processing Record 10 of Set 10 | fare
# Processing Record 11 of Set 10 | atar
# Processing Record 12 of Set 10 | tepexi
# City not found. Skipping...
# Processing Record 13 of Set 10 | jalu
# Processing Record 14 of Set 10 | lianzhou
# Processing Record 15 of Set 10 | dodge city
# Processing Record 16 of Set 10 | puerto rico
# Processing Record 17 of Set 10 | shubarkuduk
# Processing Record 18 of Set 10 | port hueneme
# Processing Record 19 of Set 10 | oussouye
# Processing Record 20 of Set 10 | rudnya
# Processing Record 21 of Set 10 | zhigansk
# Processing Record 22 of Set 10 | mandera
# Processing Record 23 of Set 10 | waddan
# Processing Record 24 of Set 10 | nioro
# Processing Record 25 of Set 10 | karachi
# Processing Record 26 of Set 10 | cascais
# Processing Record 27 of Set 10 | biri
# Processing Record 28 of Set 10 | ust-maya
# Processing Record 29 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 30 of Set 10 | sorland
# Processing Record 31 of Set 10 | xining
# Processing Record 32 of Set 10 | avera
# Processing Record 33 of Set 10 | arica
# Processing Record 34 of Set 10 | alihe
# Processing Record 35 of Set 10 | high rock
# Processing Record 36 of Set 10 | ixtapa
# Processing Record 37 of Set 10 | gourcy
# Processing Record 38 of Set 10 | lashio
# Processing Record 39 of Set 10 | praia da vitoria
# Processing Record 40 of Set 10 | longyearbyen
# Processing Record 41 of Set 10 | makakilo city
# Processing Record 42 of Set 10 | khani
# Processing Record 43 of Set 10 | aguimes
# Processing Record 44 of Set 10 | along
# Processing Record 45 of Set 10 | deputatskiy
# Processing Record 46 of Set 10 | nueva gerona
# Processing Record 47 of Set 10 | srandakan
# Processing Record 48 of Set 10 | murgab
# Processing Record 49 of Set 10 | kirkuk
# Processing Record 50 of Set 10 | roald
# Processing Record 1 of Set 11 | dongsheng
# Processing Record 2 of Set 11 | flagstaff
# Processing Record 3 of Set 11 | portland
# Processing Record 4 of Set 11 | taybad
# Processing Record 5 of Set 11 | manzanillo
# Processing Record 6 of Set 11 | micheweni
# Processing Record 7 of Set 11 | shebunino
# Processing Record 8 of Set 11 | sechura
# Processing Record 9 of Set 11 | labuhan
# Processing Record 10 of Set 11 | enshi
# Processing Record 11 of Set 11 | evensk
# Processing Record 12 of Set 11 | trebinje
# Processing Record 13 of Set 11 | bitung
# Processing Record 14 of Set 11 | manacapuru
# Processing Record 15 of Set 11 | daud khel
# Processing Record 16 of Set 11 | kahului
# Processing Record 17 of Set 11 | kutum
# Processing Record 18 of Set 11 | vieques
# Processing Record 19 of Set 11 | tuy hoa
# Processing Record 20 of Set 11 | damara
# Processing Record 21 of Set 11 | lodja
# Processing Record 22 of Set 11 | havoysund
# Processing Record 23 of Set 11 | clinton
# Processing Record 24 of Set 11 | buala
# Processing Record 25 of Set 11 | bahia honda
# Processing Record 26 of Set 11 | klaksvik
# Processing Record 27 of Set 11 | bonthe
# Processing Record 28 of Set 11 | iquique
# Processing Record 29 of Set 11 | anqing
# Processing Record 30 of Set 11 | pailon
# Processing Record 31 of Set 11 | guajara-mirim
# City not found. Skipping...
# Processing Record 32 of Set 11 | kamenka
# Processing Record 33 of Set 11 | basco
# Processing Record 34 of Set 11 | palanga
# Processing Record 35 of Set 11 | lata
# Processing Record 36 of Set 11 | bykovo
# Processing Record 37 of Set 11 | jinxiang
# Processing Record 38 of Set 11 | hami
# Processing Record 39 of Set 11 | warrington
# Processing Record 40 of Set 11 | waipawa
# Processing Record 41 of Set 11 | tirana
# Processing Record 42 of Set 11 | pimenta bueno
# Processing Record 43 of Set 11 | mahenge
# Processing Record 44 of Set 11 | bodden town
# Processing Record 45 of Set 11 | tikalaan
# City not found. Skipping...
# Processing Record 46 of Set 11 | veisiejai
# Processing Record 47 of Set 11 | villafranca de los barros
# Processing Record 48 of Set 11 | asht
# City not found. Skipping...
# Processing Record 49 of Set 11 | solovetskiy
# City not found. Skipping...
# Processing Record 50 of Set 11 | shitanjing
# Processing Record 1 of Set 12 | faya
# Processing Record 2 of Set 12 | ust-ilimsk
# Processing Record 3 of Set 12 | ewa beach
# Processing Record 4 of Set 12 | goderich
# Processing Record 5 of Set 12 | yingcheng
# Processing Record 6 of Set 12 | los llanos de aridane
# Processing Record 7 of Set 12 | newala
# Processing Record 8 of Set 12 | falealupo
# City not found. Skipping...
# Processing Record 9 of Set 12 | sao joao da barra
# Processing Record 10 of Set 12 | mizpe ramon
# City not found. Skipping...
# Processing Record 11 of Set 12 | khandyga
# Processing Record 12 of Set 12 | alamada
# Processing Record 13 of Set 12 | eldikan
# City not found. Skipping...
# Processing Record 14 of Set 12 | itatiaia
# Processing Record 15 of Set 12 | san jose
# Processing Record 16 of Set 12 | chicama
# Processing Record 17 of Set 12 | san juan
# Processing Record 18 of Set 12 | santa cruz
# Processing Record 19 of Set 12 | tutoia
# Processing Record 20 of Set 12 | cayenne
# Processing Record 21 of Set 12 | yarada
# Processing Record 22 of Set 12 | lufilufi
# Processing Record 23 of Set 12 | matiri
# Processing Record 24 of Set 12 | karlskoga
# Processing Record 25 of Set 12 | abha
# Processing Record 26 of Set 12 | liepaja
# Processing Record 27 of Set 12 | buchanan
# Processing Record 28 of Set 12 | japura
# Processing Record 29 of Set 12 | tocopilla
# Processing Record 30 of Set 12 | colac
# Processing Record 31 of Set 12 | hangu
# Processing Record 32 of Set 12 | arlit
# Processing Record 33 of Set 12 | kasongo
# Processing Record 34 of Set 12 | ola
# Processing Record 35 of Set 12 | kimbe
# Processing Record 36 of Set 12 | bol
# Processing Record 37 of Set 12 | salinopolis
# Processing Record 38 of Set 12 | dukat
# Processing Record 39 of Set 12 | kavaratti
# Processing Record 40 of Set 12 | hengshui
# Processing Record 41 of Set 12 | sangmelima
# Processing Record 42 of Set 12 | kobojango
# City not found. Skipping...
# Processing Record 43 of Set 12 | faire
# City not found. Skipping...
# Processing Record 44 of Set 12 | karpathos
# Processing Record 45 of Set 12 | yar-sale
# Processing Record 46 of Set 12 | alotau
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data = pd.DataFrame(city_weather)
city_data.head()
# Out:
#         city      lat       lon   temp  humidity  wind  cloud country  \
# 0       poum -20.2333  164.0167  79.72        75  1.14     94      NC
# 1       hilo  19.7297 -155.0900  80.60        61  8.05     75      US
# 2      vaini -21.2000 -175.2000  87.80        70  9.22     40      TO
# 3  busselton -33.6500  115.3333  66.99        97  8.03      9      AU
# 4    chongwe -15.3292   28.6820  68.00        94  2.30     75      ZM
#
#          date
# 0  1611098457
# 1  1611097816
# 2  1611098308
# 3  1611098318
# 4  1611098381

# %%
# Export Dataframe into a .csv
city_data.to_csv('cities.csv')

# %%
city_data.describe()
# Out:
#               lat         lon        temp    humidity        wind       cloud  \
# count  543.000000  543.000000  543.000000  543.000000  543.000000  543.000000
# mean    18.638653   18.663132   49.891271   72.370166    8.313057   55.145488
# std     33.369539   90.717700   32.266822   19.558060    6.078057   39.831970
# min    -54.800000 -175.200000  -56.200000   12.000000    0.250000    0.000000
# 25%     -8.253200  -63.049300   32.505000   62.000000    3.530000    9.000000
# 50%     21.283300   22.400700   62.100000   77.000000    6.910000   72.000000
# 75%     45.797950  101.465150   75.180000   87.000000   11.225000   95.000000
# max     78.218600  178.416700   95.000000  100.000000   35.680000  100.000000
#
#                date
# count  5.430000e+02
# mean   1.611098e+09
# std    1.490639e+02
# min    1.611098e+09
# 25%    1.611098e+09
# 50%    1.611099e+09
# 75%    1.611099e+09
# max    1.611099e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(city_data.lat, city_data.temp, edgecolors='black',alpha=.8)
plt.title(f'City Latitude vs. Max Temperature ({time.strftime("%x")})')
plt.grid(True)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
# Out:
# Text(0, 0.5, 'Max Temperature (F)')

# %%
#the max temp is higher in cities in the southern hemisphere (where latitude is negative)

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build the scatter plots for each city types
plt.scatter(city_data.lat, city_data.humidity, edgecolors='black',alpha=.8)
plt.title(f'City Latitude vs. Humidity ({time.strftime("%x")})')
plt.grid(True)
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")

plt.show()

# %%
# this scatterplot does not show a strong correlation between humidity and latitude - even though science shows
# the equator typically is the most humid

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build the scatter plots for each city types
plt.scatter(city_data.lat, city_data.cloud, edgecolors='black',alpha=.8)
plt.title(f'City Latitude vs. Cloudiness ({time.strftime("%x")})')
plt.grid(True)
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")

plt.show()

# %%
# There is no strong correlation between latitude and cloudiness

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for each city types
plt.scatter(city_data.lat, city_data.wind, edgecolors='black',alpha=.8)
plt.title(f'City Latitude vs. Wind Speed ({time.strftime("%x")})')
plt.grid(True)
plt.ylabel("Wind Speed (%)")
plt.xlabel("Latitude")

plt.show()

# %%
# there is no correlation between latitude and wind speed

# %% [markdown]
# ## Linear Regression

# %%
# Create two new dataframes for northern and southern hemispheres

north_hemisphere = (city_data.loc[city_data.lat>0])
south_hemisphere = (city_data.loc[city_data.lat<0])

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_hemisphere.lat ,north_hemisphere.temp)
regress_values = north_hemisphere.lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
plt.scatter(north_hemisphere.lat,north_hemisphere.temp)
plt.plot(north_hemisphere.lat,regress_values,"r-")
plt.annotate(line_eq,(10,-20),fontsize=15,color="red")
plt.title("Northern Hemisphere: Correlation of Latitude and Max Temperatures", y=1.02, fontsize=18);
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The R value (i.e. Coefficient of Correlation) is: {rvalue}")
print(f"The R squared value (i.e. Coefficient of Determination) is: {rvalue**2}")
plt.show()
# Out:
# y = -1.41x + 92.42
# The R value (i.e. Coefficient of Correlation) is: -0.8309714024477726
# The R squared value (i.e. Coefficient of Determination) is: 0.690513471686018

# %%
# the northern hemisphere shows that temperature falls farther from the equator - it is colder farther from the equator
# latitude explains the decrease in temperature 69% of the time as explained through the r squared

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_hemisphere.lat ,south_hemisphere.temp)
regress_values = south_hemisphere.lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
plt.scatter(south_hemisphere.lat,south_hemisphere.temp)
plt.plot(south_hemisphere.lat,regress_values,"r-")
plt.annotate(line_eq,(-25,60),fontsize=15,color="red")
plt.title("Southern Hemisphere: Correlation of Latitude and Max Temperatures", y=1.02, fontsize=18);
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The R value (i.e. Coefficient of Correlation) is: {rvalue}")
print(f"The R squared value (i.e. Coefficient of Determination) is: {rvalue**2}")
plt.show()
# Out:
# y = 0.32x + 79.84
# The R value (i.e. Coefficient of Correlation) is: 0.5065989780548186
# The R squared value (i.e. Coefficient of Determination) is: 0.2566425245661865

# %%
# in the Southern hemisphere, the generally as you move closer to the equator
# and the latitude is closer to 0, the temperarure rises.  Latitude explains the higher temperature 26% of the time
# as explained through the r squared value.

# latitude appears to explain more of the max temperatures in the northern hemisphere

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_hemisphere.lat ,north_hemisphere.humidity)
regress_values = north_hemisphere.lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
plt.scatter(north_hemisphere.lat,north_hemisphere.humidity)
plt.plot(north_hemisphere.lat,regress_values,"r-")
plt.annotate(line_eq,(40,20),fontsize=15,color="red")
plt.title("Northern Hemisphere: Correlation of Latitude and Humidity", y=1.02, fontsize=18);
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
print(f"The R value (i.e. Coefficient of Correlation) is: {rvalue}")
print(f"The R squared value (i.e. Coefficient of Determination) is: {rvalue**2}")
plt.show()
# Out:
# y = 0.36x + 57.5
# The R value (i.e. Coefficient of Correlation) is: 0.3456306997630202
# The R squared value (i.e. Coefficient of Determination) is: 0.119460580618675

# %%
# humidity is slightly correlated to latitude only 12% of the time in the northern hemisphere

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_hemisphere.lat ,south_hemisphere.humidity)
regress_values = south_hemisphere.lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
plt.scatter(south_hemisphere.lat,south_hemisphere.humidity)
plt.plot(south_hemisphere.lat,regress_values,"r-")
plt.annotate(line_eq,(-25,60),fontsize=15,color="red")
plt.title("Southern Hemisphere: Correlation of Latitude and Humidity", y=1.02, fontsize=18);
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
print(f"The R value (i.e. Coefficient of Correlation) is: {rvalue}")
print(f"The R squared value (i.e. Coefficient of Determination) is: {rvalue**2}")
plt.show()
# Out:
# y = 0.59x + 85.91
# The R value (i.e. Coefficient of Correlation) is: 0.46134823910704864
# The R squared value (i.e. Coefficient of Determination) is: 0.21284219772717453

# %%
# humidity is slightly correlated to latitude in the southern hemisphere, explaining it 21% of the time

# latitude doesn't appear to contribute much to humidity percentages in the northern nor southern hemispheres

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_hemisphere.lat ,north_hemisphere.cloud)
regress_values = north_hemisphere.lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
plt.scatter(north_hemisphere.lat,north_hemisphere.cloud)
plt.plot(north_hemisphere.lat,regress_values,"r-")
plt.annotate(line_eq,(40,20),fontsize=15,color="red")
plt.title("Northern Hemisphere: Correlation of Latitude and Cloudiness", y=1.02, fontsize=18);
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
print(f"The R value (i.e. Coefficient of Correlation) is: {rvalue}")
print(f"The R squared value (i.e. Coefficient of Determination) is: {rvalue**2}")
plt.show()
# Out:
# y = 0.6x + 32.13
# The R value (i.e. Coefficient of Correlation) is: 0.2963874332173502
# The R squared value (i.e. Coefficient of Determination) is: 0.08784551056916924

# %%
# there is no real correlation to latitude and cloudiness in the northern hemisphere - r squared of .09

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_hemisphere.lat ,south_hemisphere.cloud)
regress_values = south_hemisphere.lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
plt.scatter(south_hemisphere.lat,south_hemisphere.cloud)
plt.plot(south_hemisphere.lat,regress_values,"r-")
plt.annotate(line_eq,(-25,60),fontsize=15,color="red")
plt.title("Southern Hemisphere: Correlation of Latitude and Cloudiness", y=1.02, fontsize=18);
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
print(f"The R value (i.e. Coefficient of Correlation) is: {rvalue}")
print(f"The R squared value (i.e. Coefficient of Determination) is: {rvalue**2}")
plt.show()
# Out:
# y = 1.3x + 80.93
# The R value (i.e. Coefficient of Correlation) is: 0.4395346702169232
# The R squared value (i.e. Coefficient of Determination) is: 0.19319072632269946

# %%
# in the southern hemisphere, latitude explains cloudiness about 19% of the time 

# latitude impacts cloudiness more in the southern hemisphere rather than the norther hemisphere, but is
# still a weak correlation - less than 20% can be explained through latitude

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_hemisphere.lat ,north_hemisphere.wind)
regress_values = north_hemisphere.lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
plt.scatter(north_hemisphere.lat,north_hemisphere.wind)
plt.plot(north_hemisphere.lat,regress_values,"r-")
plt.annotate(line_eq,(40,20),fontsize=15,color="red")
plt.title("Northern Hemisphere: Correlation of Latitude and Wind Speed", y=1.02, fontsize=18);
plt.xlabel('Latitude')
plt.ylabel('Wind (mph)')
print(f"The R value (i.e. Coefficient of Correlation) is: {rvalue}")
print(f"The R squared value (i.e. Coefficient of Determination) is: {rvalue**2}")
plt.show()
# Out:
# y = 0.01x + 8.09
# The R value (i.e. Coefficient of Correlation) is: 0.04509342361804676
# The R squared value (i.e. Coefficient of Determination) is: 0.0020334168535966176

# %%
# in the northern hemisphere, latitude does not correlate to wind speed - r squared .002

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_hemisphere.lat ,south_hemisphere.wind)
regress_values = south_hemisphere.lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
plt.scatter(south_hemisphere.lat,south_hemisphere.wind)
plt.plot(south_hemisphere.lat,regress_values,"r-")
plt.annotate(line_eq,(-25,25),fontsize=15,color="red")
plt.title("Southern Hemisphere: Correlation of Latitude and Wind Speed", y=1.02, fontsize=18);
plt.xlabel('Latitude')
plt.ylabel('Wind (mph)')
print(f"The R value (i.e. Coefficient of Correlation) is: {rvalue}")
print(f"The R squared value (i.e. Coefficient of Determination) is: {rvalue**2}")
plt.show()
# Out:
# y = -0.13x + 5.11
# The R value (i.e. Coefficient of Correlation) is: -0.3138679880387858
# The R squared value (i.e. Coefficient of Determination) is: 0.09851311391551539

# %%
# in the southern hemisphere, latitude explains wind speed about 9% of the time, which is more than latitude explains
# wind speed in the northern hemisphere

# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json
# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
cities_df = pd.read_csv("cities.csv")
cities_df.dropna()
cities_df.head()
# Out:
#    Unnamed: 0      city      lat       lon   temp  humidity   wind  cloud  \
# 0           0     bluff -46.6000  168.3333  54.00        91  10.00     86
# 1           1   iqaluit  63.7506  -68.5145  21.20        79  16.11     90
# 2           2   rikitea -23.1203 -134.9692  78.78        73  13.02     43
# 3           3  valdivia -39.8142  -73.2459  80.60        47  10.36      0
# 4           4  victoria  22.2855  114.1577  57.00        63  17.09     47
#
#   country        date
# 0      NZ  1611012807
# 1      CA  1611012561
# 2      PF  1611012807
# 3      CL  1611012808
# 4      HK  1611012809

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
# Configure gmaps with API key
gmaps.configure(api_key=g_key)

# Store 'Lat' and 'Lng' into  locations
locations = cities_df[["lat", "lon"]]
humidity = cities_df["humidity"].astype(float)

# %%
# Plot Heatmap
fig = gmaps.figure(center = [0,0] ,zoom_level = 2)

#Create and add heat layer 
heat_layer = gmaps.heatmap_layer(locations, weights=humidity,
                               dissipating=False, max_intensity=100,
                               point_radius = 4)
fig.add_layer(heat_layer)
#Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
weather_file=cities_df.loc[(cities_df['temp']>=70)&(cities_df['temp']<=80)]
wind_file=weather_file.loc[(weather_file['wind']<=10)]
ideal_weather=wind_file.loc[(wind_file['cloud']==0)]
ideal_weather.dropna
ideal_weather.head()
# Out:
#     Unnamed: 0            city      lat       lon   temp  humidity  wind  \
# 23          23       caravelas -17.7125  -39.2481  76.32        83  7.34
# 31          31           pisco -13.7000  -76.2167  73.40        73  8.05
# 82          82      el burrion  25.5333 -108.4000  79.00        32  3.00
# 86          86         yenagoa   4.9247    6.2642  77.41        89  4.47
# 96          96  saint-philippe -21.3585   55.7679  78.80        73  5.75
#
#     cloud country        date
# 23      0      BR  1611012815
# 31      0      PE  1611012818
# 82      0      MX  1611012835
# 86      0      NG  1611012836
# 96      0      RE  1611012838

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df = ideal_weather.reset_index(drop=True)
hotel_df["Hotel Name"] = ""
hotel_df
# Out:
#     Unnamed: 0            city      lat       lon   temp  humidity  wind  \
# 0           23       caravelas -17.7125  -39.2481  76.32        83  7.34
# 1           31           pisco -13.7000  -76.2167  73.40        73  8.05
# 2           82      el burrion  25.5333 -108.4000  79.00        32  3.00
# 3           86         yenagoa   4.9247    6.2642  77.41        89  4.47
# 4           96  saint-philippe -21.3585   55.7679  78.80        73  5.75
# 5          139    saint-joseph -21.3667   55.6167  78.80        73  5.75
# 6          187          tamale   9.4008   -0.8393  79.61        16  5.55
# 7          306       saint-leu -21.1500   55.2833  78.80        73  5.75
# 8          329           warri   5.5167    5.7500  77.81        87  2.21
# 9          367         cradock -32.1642   25.6192  70.45        63  2.15
# 10         420        san luis -33.2950  -66.3356  73.71        30  6.98
# 11         469        cabedelo  -6.9811  -34.8339  78.80        83  6.91
# 12         536         mankono   8.0586   -6.1897  75.99        23  1.97
#
#     cloud country        date Hotel Name
# 0       0      BR  1611012815
# 1       0      PE  1611012818
# 2       0      MX  1611012835
# 3       0      NG  1611012836
# 4       0      RE  1611012838
# 5       0      RE  1611012856
# 6       0      GH  1611012684
# 7       0      RE  1611012917
# 8       0      NG  1611012923
# 9       0      ZA  1611012934
# 10      0      AR  1611012789
# 11      0      BR  1611012964
# 12      0      CI  1611012988

# %%
# params dictionary to update each iteration
params = {
    "radius": 50000,
    "types": "hotel",
    "keyword": "hotels",
    "key": g_key
}

# Use the lat/lng we recovered to identify hotels
for index, row in hotel_df.iterrows():
    
    # get lat, lng 
    lat = row["lat"]
    lng = row["lon"]
    
    # change location each iteration while leaving original params in place
    params["location"] = f"{lat},{lng}"
    
    # Use the search term: "Hotels" and our lat/lng
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
    # make request and print url
    hotel_name = requests.get(base_url, params=params)
    
    # convert to json
    hotel_name = hotel_name.json()
    print(json.dumps(hotel_name, indent=4, sort_keys=True))
    
    # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotel_name["results"][0]["name"]
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "ATtYBwJQVN-aWAwpnXyCtLwehjNYi_-R6G7dkx6a3w_dDTIeMzaRLqxiMa1DTbQtOHgby-FUs6_4_MFicZfKc8BvYl9kW_-YtCLnZgGiCHOgBVBplmWxqN1u7MpMS7JhxqHyzwQVrolYbY8vNx60iN8Xm3DrSO8HUrmYHmovFjsHAh3ZyLckHDGbj8V3CbJguXP65qcMr7nCK4tchGCtj1Zla7o-AkNhpJQEgDjmPy71TfvmSFNIsIczLydGW0adJlTcErKlinNRl2eZG3Jgf1GOUVzisJHrUSjSfSF8VrCTp_AN17QtNfvvFVXMF7IwLRXF7-T0O8vEnMVbI7jBVsFNR8nnxFFYfNilC-jkFURTdJYOCSR0jsPiqop40QTfS4muNJg3xc_-I-nItczQnXcGJi2AusJHqj3EIQGY5uuCmw43jLj6fcwZ1iTGv-XYIwN8",
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.3364849,
#                     "lng": -39.2215417
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.33517002010727,
#                         "lng": -39.22008152010728
#                     },
#                     "southwest": {
#                         "lat": -17.33786967989272,
#                         "lng": -39.22278117989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Pousada Casa de Maria",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2624,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106351209071775310455\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwKyZByJsW-pHA78DscVDjodxSskBfhHmWPLREBqpg0GZY8V4Piq27wU2_ENCgT0iGtauNP9AQJ33PJ-xTYZzOTFGKgoWT-8pYAmrbdCXCKkCTK4hD3lhQLfiW23GcqgBbwhW9wMjqop3qbQNSUKrsMlGQZCNRQcX68GR5xGVdX_Nijf",
#                     "width": 3936
#                 }
#             ],
#             "place_id": "ChIJLx3x0bL-NAcRwhLfkDGhMzo",
#             "plus_code": {
#                 "compound_code": "MQ7H+C9 Prado, State of Bahia, Brazil",
#                 "global_code": "59J2MQ7H+C9"
#             },
#             "rating": 4.7,
#             "reference": "ChIJLx3x0bL-NAcRwhLfkDGhMzo",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 653,
#             "vicinity": "R. Joaquim Dami\u00e3o de Almeida, 60 - Novo Prado, Prado"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.337028,
#                     "lng": -39.2196894
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.33580097010728,
#                         "lng": -39.21838002010728
#                     },
#                     "southwest": {
#                         "lat": -17.33850062989272,
#                         "lng": -39.22107967989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Pousada Guaratiba",
#             "photos": [
#                 {
#                     "height": 3456,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109927291274954212735\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwL1nUCI0uI2Ox54SGFnkANMA34jijDpNpZO9KW_B7k6nhyY-Da2JqoahNUWzBWyJhGQtnc4DjnTiUoHF7vxjOZMfif53I-6LLz82rU-i7ZgZogq6TTKmTFKlYH9NIoxlgt4t8vwGlmVnjYFngf6nOkevl6_mImAvmm1Sho8IHtdysl-",
#                     "width": 4608
#                 }
#             ],
#             "place_id": "ChIJqQzXhV75NAcRNZdLphwVJZQ",
#             "plus_code": {
#                 "compound_code": "MQ7J+54 Prado, State of Bahia, Brazil",
#                 "global_code": "59J2MQ7J+54"
#             },
#             "rating": 4.6,
#             "reference": "ChIJqQzXhV75NAcRNZdLphwVJZQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 428,
#             "vicinity": "25 R, R. Moises Santos Almeida - Prado de novo, Prado"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.3427428,
#                     "lng": -39.2183836
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.34139367010728,
#                         "lng": -39.21701347010727
#                     },
#                     "southwest": {
#                         "lat": -17.34409332989272,
#                         "lng": -39.21971312989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "La Isla Ecoresort",
#             "photos": [
#                 {
#                     "height": 1456,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116426936626927632998\">Withor Souza Santos</a>"
#                     ],
#                     "photo_reference": "ATtYBwJrZwj2r5ELXtoKcQtco8nTKh8jjo9Rc1Z-l7oKxXPIJWB_iEnNwE2ANaIZTkyByHSg7h87wxsGpbDl0RR29Xw2TjLnyHdOLQNNnXZVBnPdagDPHQDgGLI4dF0n1PkVA24EvtlDot-bhSexqKLhfzEolXK-_8WO_7FcpragpMDQVdQR",
#                     "width": 2592
#                 }
#             ],
#             "place_id": "ChIJnZnwDML7NAcRIrnnRiQqV78",
#             "plus_code": {
#                 "compound_code": "MQ4J+WJ Prado, State of Bahia, Brazil",
#                 "global_code": "59J2MQ4J+WJ"
#             },
#             "rating": 4,
#             "reference": "ChIJnZnwDML7NAcRIrnnRiQqV78",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 58,
#             "vicinity": "R. S\u00e3o Benedito, 52, Prado"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.3350743,
#                     "lng": -39.218218
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.33374692010728,
#                         "lng": -39.21701302010728
#                     },
#                     "southwest": {
#                         "lat": -17.33644657989272,
#                         "lng": -39.21971267989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Cahy Praia Hotel",
#             "photos": [
#                 {
#                     "height": 3000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117897445869257290519\">josue botazine</a>"
#                     ],
#                     "photo_reference": "ATtYBwKuhlfbVLQIG3dhcRMTNCWY3GgXVUa4v35C5dl66ZTaQ2Ckry7lszesS2n0Mo-7pbkcKbPvvpJUzMkMa9uI5eIGPPEDb851Xxj_CE2pYXe9hgDCsgS18qF2wrAqfDSNL8aN-843ynGugy4t2npLj7R7nSOGhHnykPhZv-mdS-1fLGf0",
#                     "width": 4000
#                 }
#             ],
#             "place_id": "ChIJt30sSFr5NAcRSlaoNUoVYIs",
#             "plus_code": {
#                 "compound_code": "MQ7J+XP Prado, State of Bahia, Brazil",
#                 "global_code": "59J2MQ7J+XP"
#             },
#             "rating": 4.5,
#             "reference": "ChIJt30sSFr5NAcRSlaoNUoVYIs",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 615,
#             "vicinity": "Rua Conjunto das Mans\u00f5es s/n - Lagoa Pequena, Prado"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.538036,
#                     "lng": -39.192935
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.53675257010728,
#                         "lng": -39.19158557010729
#                     },
#                     "southwest": {
#                         "lat": -17.53945222989272,
#                         "lng": -39.19428522989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Pousada Paradise",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103535356609079107517\">Pousada Paradise</a>"
#                     ],
#                     "photo_reference": "ATtYBwIv2vCWrhJMfX3O-olrKPnJfXjihKwsAUF0hUYnUsXpgTC2TXWrdgoNSLM67hYNY3pfu522Af-tDd8OUhhYVlzmY6hbsKPTMZ6ZKH3YPr1V1bXOPw_-K14AwI53uuYuP_drSxLcU4t39oFmazVy2Ql7y6eVjKnTBwY4v7_tI19_ljjo",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJu9OIhVbmNAcRv_9iigr7fgU",
#             "plus_code": {
#                 "compound_code": "FR64+QR Alcoba\u00e7a, State of Bahia, Brazil",
#                 "global_code": "59J2FR64+QR"
#             },
#             "rating": 4.3,
#             "reference": "ChIJu9OIhVbmNAcRv_9iigr7fgU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 54,
#             "vicinity": "R. Des. Mello Rocha, 309 - Centro, Alcoba\u00e7a"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.8998825,
#                     "lng": -39.37560190000001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.89854737010728,
#                         "lng": -39.37425072010727
#                     },
#                     "southwest": {
#                         "lat": -17.90124702989272,
#                         "lng": -39.37695037989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Franz Beach Hotel",
#             "photos": [
#                 {
#                     "height": 5312,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104655558551589124356\">Tiago Souza Nunes</a>"
#                     ],
#                     "photo_reference": "ATtYBwKvbFAFyBDLIULDmkMMbq9HLL4sDF_Fchikcip0cKr71mmfHTyfAiFamcD13lPkDPfIigo1AWFCg9sDkQC2OVDLYMdYTCvrpzP7B0p2AG1ux-gbb3PDXFzcVN8NTyAOtsb6jOAEuHmBJOj6s8bQ5bP2MEYPMBK9T9KcyCLOYpYt-Kbn",
#                     "width": 2988
#                 }
#             ],
#             "place_id": "ChIJD0PIBVvUygARmnyRWXw1puY",
#             "plus_code": {
#                 "compound_code": "4J2F+2Q Nova Vi\u00e7osa, State of Bahia, Brazil",
#                 "global_code": "59J24J2F+2Q"
#             },
#             "rating": 4.8,
#             "reference": "ChIJD0PIBVvUygARmnyRWXw1puY",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 5,
#             "vicinity": "BA 001 Costa do Atl\u00e2ntico, 10, R. Mucuri - para, Nova Vi\u00e7osa"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.9132082,
#                     "lng": -39.3905475
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.91145772010728,
#                         "lng": -39.38934072010728
#                     },
#                     "southwest": {
#                         "lat": -17.91415737989272,
#                         "lng": -39.39204037989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Pousada Cheiro de Mar",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 493,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100557575766287026296\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwJI6WqlbmO1lpgBifZyG8A4bYEfxEXNQJ_e0XyZIIu0z6mADmHuMcYR3n8HjQf5f4J4Xpl9fKTMeqck8oiHdRS3g-iNw3w5LGizWXoV0bpfgd_dAnvOh9sAxL_z_U1ok8GuNb2sD8r3A8OXp2nIV4XpS0nxGuy_1gg4QtG6rwJnq5hc",
#                     "width": 791
#                 }
#             ],
#             "place_id": "ChIJDz0jfBHUygARX7wiVcdh7sk",
#             "plus_code": {
#                 "compound_code": "3JP5+PQ Nova Vi\u00e7osa, State of Bahia, Brazil",
#                 "global_code": "59J23JP5+PQ"
#             },
#             "rating": 4.4,
#             "reference": "ChIJDz0jfBHUygARX7wiVcdh7sk",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 192,
#             "vicinity": "Av. Oce\u00e2nica, 3479 - Sabacui, Nova Vi\u00e7osa"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.3402906,
#                     "lng": -39.2179416
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.33911107010728,
#                         "lng": -39.21673257010728
#                     },
#                     "southwest": {
#                         "lat": -17.34181072989272,
#                         "lng": -39.21943222989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Mar & Sol Praia Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3474,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104862610205909722454\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwIONuZ70BhW8f97pb6s-EGQnLgboMGAidKJdDeQeGcbagMiOegaYab-RTY20S253xGlPmCTnLXs_GpdaLwKhTEyAGBRYz_II2Jpmfi7GXTOwQHsPIa83EvIjvyty21k9UB6OcWJ1K5k6VVELgjO-2EJP3NG6PvvaJhda-J2KMRRAA3m",
#                     "width": 4632
#                 }
#             ],
#             "place_id": "ChIJfRJJFFH5NAcR3SEE1wqc9YY",
#             "plus_code": {
#                 "compound_code": "MQ5J+VR Prado, State of Bahia, Brazil",
#                 "global_code": "59J2MQ5J+VR"
#             },
#             "rating": 4,
#             "reference": "ChIJfRJJFFH5NAcR3SEE1wqc9YY",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 447,
#             "vicinity": "R. Dom Pedro, 330 - Centro, Prado"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.8947531,
#                     "lng": -39.364593
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.89344517010728,
#                         "lng": -39.36327492010728
#                     },
#                     "southwest": {
#                         "lat": -17.89614482989272,
#                         "lng": -39.36597457989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Pousada Iracema",
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112235176178289045830\">Bruno Ciscotto</a>"
#                     ],
#                     "photo_reference": "ATtYBwKJtbGJ-rCgo-LhPbjg_wnZCFUYLbBSE1eF9HSMYFbqTNAHjQaxPYQcczK42LhJWRviZ_v6A1eIfwk9ofVd8385aCltywIGDR4RA683KMrUtscHl-GnZnuUVw_wGb7Xv8T_eU8SjMgAKX0ij7x5WyfvWR0J-nkmZu5G448L0YbWGAXD",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJNUGPgP_UygARu1z8Vi0V1UE",
#             "plus_code": {
#                 "compound_code": "4J4P+35 Nova Vi\u00e7osa, State of Bahia, Brazil",
#                 "global_code": "59J24J4P+35"
#             },
#             "rating": 4.5,
#             "reference": "ChIJNUGPgP_UygARu1z8Vi0V1UE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 193,
#             "vicinity": "Av. do Aeroporto, 499, Nova Vi\u00e7osa"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.5388631,
#                     "lng": -39.7140114
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.53757302010728,
#                         "lng": -39.71269122010728
#                     },
#                     "southwest": {
#                         "lat": -17.54027267989272,
#                         "lng": -39.71539087989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Pousada Lord",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 963,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115780552322096238227\">Pousada Lord</a>"
#                     ],
#                     "photo_reference": "ATtYBwKBpH1Qq8fEJkcPzewCdhN4wo8JgWT1KyAsFe3EtTHSVSksxCYavrqn5hHl2TblJw34EV7SH36RCFxHBhYzPzlhpSpAQcErIRt-Fl5vJj4hoXhi05SAS7Bg47EHXVMQHwtfhx4cGtcb_nVfLkKDfUdpYdfzM_Zbaum-mtF7Qw-h58Yb",
#                     "width": 1920
#                 }
#             ],
#             "place_id": "ChIJVa9XjicTNQcRzKQtqpnFxm8",
#             "plus_code": {
#                 "compound_code": "F76P+F9 Castelinho, Teixeira de Freitas - State of Bahia, Brazil",
#                 "global_code": "59J2F76P+F9"
#             },
#             "rating": 4.5,
#             "reference": "ChIJVa9XjicTNQcRzKQtqpnFxm8",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 774,
#             "vicinity": "Rodovia BR 101, Km 878 - Castelinho"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.3429108,
#                     "lng": -39.2170016
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.34155927010728,
#                         "lng": -39.21561582010727
#                     },
#                     "southwest": {
#                         "lat": -17.34425892989272,
#                         "lng": -39.21831547989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Amendoeiras Praia",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 853,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105289033183959138828\">Praia Hotel Amendoeiras</a>"
#                     ],
#                     "photo_reference": "ATtYBwLPWcsTGjaAk0NXyac1yBVPi9zbwIuPJX0vmqqzFVs21Qfld4ZYaKutaNdina_CFg1_1aSlyl8d9EQKTAn0Z4mMU3ImVE40XezRyyGLy58nn5oXKE__Xth_vEyK-pEDodXDkJPfUFnvRWANTp2lxWKtVlJNN5B7c1HxFr5fO75IVwPc",
#                     "width": 1280
#                 }
#             ],
#             "place_id": "ChIJG-IiEuD7NAcRSlquXZmWr08",
#             "plus_code": {
#                 "compound_code": "MQ4M+R5 Prado, State of Bahia, Brazil",
#                 "global_code": "59J2MQ4M+R5"
#             },
#             "rating": 4.3,
#             "reference": "ChIJG-IiEuD7NAcRSlquXZmWr08",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 358,
#             "vicinity": "Prado"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.3402012,
#                     "lng": -39.2199102
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.33879892010728,
#                         "lng": -39.21854342010727
#                     },
#                     "southwest": {
#                         "lat": -17.34149857989272,
#                         "lng": -39.22124307989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Belved\u00e9re Marujo da G\u00e1vea",
#             "photos": [
#                 {
#                     "height": 2592,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112567992189646619077\">Augusto Andrade</a>"
#                     ],
#                     "photo_reference": "ATtYBwK5DWRxxUYr7coL11IcoHObGli3C6QL03HXMX9t53WT6pjRo6VcD3JYlZAtE-qkOEsEHzeXPcTNIa_Qqw0-d-p6LOXxkLYHKFtLRjqFlJ_S-KGA25g3fxj86bI37KXl9xoT8BQhAZrairJgCkAu01tNfV17i6cnNlYi8aTcwc64MfLw",
#                     "width": 4608
#                 }
#             ],
#             "place_id": "ChIJy19sC1_5NAcROuz7u7D7eYE",
#             "plus_code": {
#                 "compound_code": "MQ5J+W2 Prado, State of Bahia, Brazil",
#                 "global_code": "59J2MQ5J+W2"
#             },
#             "rating": 4.7,
#             "reference": "ChIJy19sC1_5NAcROuz7u7D7eYE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 14,
#             "vicinity": "Av. Joana Ang\u00e9lica, 153, Prado"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.325054,
#                     "lng": -39.223909
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.32359462010728,
#                         "lng": -39.22257347010729
#                     },
#                     "southwest": {
#                         "lat": -17.32629427989272,
#                         "lng": -39.22527312989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Inn Coral Fire",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 465,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114654093322000240399\">Pousada Coral de Fogo</a>"
#                     ],
#                     "photo_reference": "ATtYBwL5UQ1h4-PzQCCMAAVZSeve6OCHb-gHd8bbcvnD0WqISTqRVP8CYfZAXqkBDXs8DKk7llu6VU3PpRwDOE9jbLfcsYyRXHxwlGGBFR95p481SDRJrxaW7okCDB6qeNPLqmDBhTL8CfaAWwm0v-sbam5eJvO_64VrN2I4C99VrSbsIplK",
#                     "width": 720
#                 }
#             ],
#             "place_id": "ChIJ3YIHhkb5NAcRZqRDwoT-6eQ",
#             "plus_code": {
#                 "compound_code": "MQFG+XC Prado, State of Bahia, Brazil",
#                 "global_code": "59J2MQFG+XC"
#             },
#             "rating": 4.6,
#             "reference": "ChIJ3YIHhkb5NAcRZqRDwoT-6eQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 115,
#             "vicinity": "R. L. Treze, quadra 23 - Basevi, Prado"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.5227896,
#                     "lng": -39.1946429
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.52144242010728,
#                         "lng": -39.19331007010727
#                     },
#                     "southwest": {
#                         "lat": -17.52414207989272,
#                         "lng": -39.19600972989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "OYO Pousada Praia Do Farol",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 768,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115409423068022058996\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwKYWGzyymyvMHW4ahqlgCvXVljzlIIfplVDfywOHEN4t6OysNypxGo89T3YI339otKTkignu5Z_Wd0yWqao-VHD9RvsQrqenIbnNWj809uJLarxoQyDjLkjJ5Oe0UBQEq1J9GDHnd2JwpAGRcyvN5OM4rPs-dYuIk6VBORjHD9ES4Mq",
#                     "width": 1024
#                 }
#             ],
#             "place_id": "ChIJeYBDDWDmNAcRcjIoY8573Us",
#             "plus_code": {
#                 "compound_code": "FRG4+V4 Alcoba\u00e7a, State of Bahia, Brazil",
#                 "global_code": "59J2FRG4+V4"
#             },
#             "rating": 4.1,
#             "reference": "ChIJeYBDDWDmNAcRcjIoY8573Us",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 107,
#             "vicinity": "RUA 10 1641, Av. Sete de Setembro, Alcoba\u00e7a"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.5467947,
#                     "lng": -39.1908693
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.54544922010728,
#                         "lng": -39.18958417010728
#                     },
#                     "southwest": {
#                         "lat": -17.54814887989272,
#                         "lng": -39.19228382989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Brisa dos Abrolhos",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106632961851296129101\">Fernando Lopes</a>"
#                     ],
#                     "photo_reference": "ATtYBwKXXK-gTvW7_6DHuFBTNnSpV8Ewkc8O31PWEW_2gK08Tf2xh5MTG6tGTQ4YqUqWnAG7SzS03evwJRuf1v_QM0VJBZdOvLBIlsKWZrk4vniRst2r66dljAeOQGC6D2zZPTCAHXhfvaOuaWMM7ZVbCUvSohSjr3D6fjeGbRFt-ZLYcEJl",
#                     "width": 4000
#                 }
#             ],
#             "place_id": "ChIJtX9QuRbnNAcRpkPhyPW3qkw",
#             "plus_code": {
#                 "compound_code": "FR35+7M Alcoba\u00e7a, State of Bahia, Brazil",
#                 "global_code": "59J2FR35+7M"
#             },
#             "rating": 4.4,
#             "reference": "ChIJtX9QuRbnNAcRpkPhyPW3qkw",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 10,
#             "vicinity": "Tv. Silva Jardim, 1657, Alcoba\u00e7a"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.2902751,
#                     "lng": -39.2231112
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.28900162010728,
#                         "lng": -39.22186762010728
#                     },
#                     "southwest": {
#                         "lat": -17.29170127989272,
#                         "lng": -39.22456727989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Pousada das Fal\u00e9sias",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2322,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113018129083513971371\">MARIA DAS GRA\u00c7AS SOUSA MACEDO</a>"
#                     ],
#                     "photo_reference": "ATtYBwJFMJ-8OZ0nrOpJWPgauXdAlADuJBl8ZHcsH0a9pl6HtHk0zxrsB5fiR6WioJp7VKpiHZ2iyKZOmbl9Ofj1SwRBBfS-lFUTZQ2z50-SyCykToaiKTFsvqtSD3MHU7YxdHRznLWSH_9WrwJZ0_fhaDSRhdPX86L74Cm9v2FktOUi9sQz",
#                     "width": 4128
#                 }
#             ],
#             "place_id": "ChIJpZFUMrP5NAcR3blp0larMOk",
#             "plus_code": {
#                 "compound_code": "PQ5G+VQ Prado, State of Bahia, Brazil",
#                 "global_code": "59J2PQ5G+VQ"
#             },
#             "rating": 4.7,
#             "reference": "ChIJpZFUMrP5NAcR3blp0larMOk",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 65,
#             "vicinity": "BA-001, Prado"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.726083,
#                     "lng": -39.178418
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.72475552010728,
#                         "lng": -39.17707292010728
#                     },
#                     "southwest": {
#                         "lat": -17.72745517989272,
#                         "lng": -39.17977257989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Marina Porto Abrolhos",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 848,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112826211240669038792\">Mpa Hotelaria e Turismo</a>"
#                     ],
#                     "photo_reference": "ATtYBwJODWuPjwf44MEdb8gnIPdMzNpP64DPkYquyaVjqFGuvlfv8oJO-DtaNUkwfZVLRv3xWj2RA_2VABGYhLDGW_R1KaTpnmgLXp9AMgSXM9zpDYiMwQxKwIpmfPeKBfVOL5kGLnzjMf9SIC7pdP3xUBR3qdA4CAjm4DNXZ20UbndBTFl3",
#                     "width": 2474
#                 }
#             ],
#             "place_id": "ChIJ0YzQ-IPaNAcRa4buc6teeTA",
#             "plus_code": {
#                 "compound_code": "7RFC+HJ Barra de Caravelas, Caravelas - State of Bahia, Brazil",
#                 "global_code": "59J27RFC+HJ"
#             },
#             "rating": 4.4,
#             "reference": "ChIJ0YzQ-IPaNAcRa4buc6teeTA",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 178,
#             "vicinity": "rua leucio siquara - Barra de Caravelas, Caravelas"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -18.0739324,
#                     "lng": -39.5403072
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -18.07243207010728,
#                         "lng": -39.53887772010728
#                     },
#                     "southwest": {
#                         "lat": -18.07513172989272,
#                         "lng": -39.54157737989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Pousada Kambuk\u00e1",
#             "photos": [
#                 {
#                     "height": 1080,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108723784792008266845\">Cristiano Lopes</a>"
#                     ],
#                     "photo_reference": "ATtYBwLa8K7nggXS9ag15ZRNPCY4xiXVVfjlpCB60VWly-QPVUa226gONxyK80wKGHkAkaXBuPYF2FZaPKCNWpMSZBH8wQDEoXCcchA-KCT6jHL3UhX6LXau8edDQdMrqmQ1O061s0dBbM_zdWKQ6FVcwCrXHpTNRf0urmiUmikLUIUNkXw1",
#                     "width": 1920
#                 }
#             ],
#             "place_id": "ChIJkZXcnrfDygARpBAD8y4KDPU",
#             "plus_code": {
#                 "compound_code": "WFG5+CV Mucuri, State of Bahia, Brazil",
#                 "global_code": "59H2WFG5+CV"
#             },
#             "rating": 4.2,
#             "reference": "ChIJkZXcnrfDygARpBAD8y4KDPU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 474,
#             "vicinity": "R. Ant\u00f4nio Carlos Magalh\u00e3es, 77 - Por do sol, Mucuri"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.525083,
#                     "lng": -39.193583
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.52374682010728,
#                         "lng": -39.19229887010729
#                     },
#                     "southwest": {
#                         "lat": -17.52644647989272,
#                         "lng": -39.19499852989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Pousada P\u00e9 de Caju",
#             "photos": [
#                 {
#                     "height": 1080,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116400910568997118719\">Pereira Souza</a>"
#                     ],
#                     "photo_reference": "ATtYBwIbB4NTsCWLWMWHyU3Nb72TQdjhv6byuQtC1mEnn-sYsSSuTp0DAkkBa1HrRgGdLAZX8-sPsT6635vF07uNHuSKPyhorN63oT7DBOI2uV_VcaR-fZTtK5qjHFAG_xx3sRp6Nr0XUk49-Hm3_pKgnKAoLgXCQy_sLXD2jh1COKd7q3QW",
#                     "width": 1920
#                 }
#             ],
#             "place_id": "ChIJFxWuyl_mNAcRdP2_Sm6nWJk",
#             "plus_code": {
#                 "compound_code": "FRF4+XH Alcoba\u00e7a, State of Bahia, Brazil",
#                 "global_code": "59J2FRF4+XH"
#             },
#             "rating": 4.1,
#             "reference": "ChIJFxWuyl_mNAcRdP2_Sm6nWJk",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 291,
#             "vicinity": "Av. Sete de Setembro, 1834, Alcoba\u00e7a"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.3444554,
#                     "lng": -39.2196679
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.34311662010727,
#                         "lng": -39.21828212010728
#                     },
#                     "southwest": {
#                         "lat": -17.34581627989272,
#                         "lng": -39.22098177989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "INN CORNER RIVER - PRADO - BAHIA - HOUSING AND HOTEL",
#             "photos": [
#                 {
#                     "height": 826,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108990553250531730938\">POUSADA CANTO DO RIO - PRADO - BAHIA - HOSPEDAGEM E HOTEL</a>"
#                     ],
#                     "photo_reference": "ATtYBwLGgjtvvtIWbMZj_o-iFdfc4wGEEWr5WSdeJp9mgShuDAU8ibhXEbOwYxrImT6ry2ALWENTs2p2Rk2mehJ0uzVA8V9IBpdJsAeH3aSDMttG0YswrZ5hQ1msRoxKss33OVXCkdL02yY-_XpBqDoc8ZscUTZL8zv4dbS6NFkMD6fd4Pem",
#                     "width": 1181
#                 }
#             ],
#             "place_id": "ChIJ2XKlBOH7NAcRVj5xPuMkEv8",
#             "plus_code": {
#                 "compound_code": "MQ4J+64 Prado, State of Bahia, Brazil",
#                 "global_code": "59J2MQ4J+64"
#             },
#             "rating": 4.5,
#             "reference": "ChIJ2XKlBOH7NAcRVj5xPuMkEv8",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 179,
#             "vicinity": "Rua Alfredo Horcades, 73 - Centro, Prado"
#         }
#     ],
#     "status": "OK"
# }
# {
#     "html_attributions": [],
#     "next_page_token": "ATtYBwLo--kgPh9l98LGywErT1V0GwvryRcBU8ikvtu2Omb6YW-2e7Hl-0xGnKzU-rb81_7U5awCkuB5xNx8F8rtAS84eRq0IKmQFY6K6HvYFKYnY4VEYcg67eJc-Frk9RLGP1gm-oCE4vltxBnYPsvJjzAtRTywkaU2amqIqu-9zR69W3I4sQALgubgHsM-i1uoDUxBwdljPgNkG0ROa_amZI2iSIp1h_-b3ur6yrNc15bdodRjQFkLgMT8LQygAZ7-rHqgAjW5N3283vbVC3_FFApmmoEOIjllyhd27t-cYIRaKQ7mBc8GIa5s4sJG18AZHAVP0YApLc-9gJnLm9XbabnmbUwPc5RAgVzKlb81j_DqfnaKBH6zrwLgIcnPxK3DXp7h9vOW-fGNoGf6so_mNXfScfiqjgjp7ltgX6CbrYZyxoF95tRvPwCl-vM40QXj",
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -13.8362619,
#                     "lng": -76.2541983
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -13.83495102010728,
#                         "lng": -76.25282897010729
#                     },
#                     "southwest": {
#                         "lat": -13.83765067989272,
#                         "lng": -76.25552862989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Paracas, a Luxury Collection Resort, Paracas",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1366,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115807317289267035339\">Hotel Paracas, A Luxury Collection Resort</a>"
#                     ],
#                     "photo_reference": "ATtYBwIqccy-oFg40HKJMDAXeYxxEuP9bDUA1Z8AzRrcreQ7CY_Pbr4K-RwrM7IiB5ZgiTS1hmMRdl0_QjmHLMWN1YXRhUzvbSevXkMFVTrHibFmjfGFi6FQ-h81Z5PJrUv5dzL37li-zgj0gJ0EGasGeJC86PLwnNNvoskL784C4L3KbOGW",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJr1CMqyRjEJERQ6vnMFFz0B4",
#             "plus_code": {
#                 "compound_code": "5P7W+F8 Paracas, Peru",
#                 "global_code": "57R55P7W+F8"
#             },
#             "rating": 4.7,
#             "reference": "ChIJr1CMqyRjEJERQ6vnMFFz0B4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2129,
#             "vicinity": "Via a Paracas S/N, Paracas"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -14.0477062,
#                     "lng": -75.7528004
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -14.04651637010728,
#                         "lng": -75.75124737010727
#                     },
#                     "southwest": {
#                         "lat": -14.04921602989272,
#                         "lng": -75.75394702989271
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Las Dunas",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1306,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108346132465140046735\">Hotel Las Dunas</a>"
#                     ],
#                     "photo_reference": "ATtYBwIOigJcud5QWo0rMkjk4-gKBzNZl2DPmtPHRVx25o5yBw4RLOr7CRKmbwi6meIdOyGsicOyGfFaqr-3HSYyVjDD5PBOPm75lx9y-8F70bLVfFZpys-go6CTpsoQ8XpeQzrcaLZxsWyHMWMJYRGWyqGoviYHzFuoDy3vIsK_GHWz5q1h",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJ7x_7gtPiEJERsUHKUhqjj1s",
#             "plus_code": {
#                 "compound_code": "X62W+WV Ica, Peru",
#                 "global_code": "57Q6X62W+WV"
#             },
#             "rating": 4.6,
#             "reference": "ChIJ7x_7gtPiEJERsUHKUhqjj1s",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2420,
#             "vicinity": "Av La Angostura 400, Ica"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -13.8274038,
#                     "lng": -76.24565559999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -13.82603082010728,
#                         "lng": -76.24448987010727
#                     },
#                     "southwest": {
#                         "lat": -13.82873047989272,
#                         "lng": -76.24718952989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Aranwa Paracas Resort & Spa",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 597,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112014084209174624983\">Aranwa Paracas Resort &amp; Spa</a>"
#                     ],
#                     "photo_reference": "ATtYBwIvvZMuKptMvC5bNMLvq3P6Oga2rNQPye78Fe-yo_6_QmXgOGiEwUCJAH07bAFFI3UgrQ2fcx1-GdmsdLXaoZN_3BwVjORiRMzFfbxHC5m9Uop40iOgL_H6UmS6-iNpLKuOx0mFLNpbL10hdiDW-Xs9vtp7z2ysnMCrNJDTg4ilSkOj",
#                     "width": 1181
#                 }
#             ],
#             "place_id": "ChIJDXi-nxVjEJERCuziY-tkO4U",
#             "plus_code": {
#                 "compound_code": "5QF3+2P Paracas, Peru",
#                 "global_code": "57R55QF3+2P"
#             },
#             "rating": 4.4,
#             "reference": "ChIJDXi-nxVjEJERCuziY-tkO4U",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2023,
#             "vicinity": "El Chaco, La Puntilla lote C, Paracas"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -13.8553751,
#                     "lng": -76.25117159999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -13.85402527010728,
#                         "lng": -76.24982177010726
#                     },
#                     "southwest": {
#                         "lat": -13.85672492989272,
#                         "lng": -76.25252142989271
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel la hacienda bahia paracas",
#             "photos": [
#                 {
#                     "height": 3464,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114111505476878100012\">Carlos Roman Oliva</a>"
#                     ],
#                     "photo_reference": "ATtYBwIxf0k13SnGcGzCwml6BSJ15WyhkYz5jzy8eLgunXt0hV2AcGGSxSDVlZwiRefavU8BbQX2-tMAad5YUTJckGXvUCG8ngnhnX3lTuoDgeeKciE6VtsjJYkBhzvWW8BiXij9uzO9zZ5ldaLGANuiL-QCI4p5RCY9gOukaXjs5S4LEPzC",
#                     "width": 4618
#                 }
#             ],
#             "place_id": "ChIJt7FO2dxiEJERJebtlmFMMAs",
#             "plus_code": {
#                 "compound_code": "4PVX+RG Paracas, Peru",
#                 "global_code": "57R54PVX+RG"
#             },
#             "rating": 4.6,
#             "reference": "ChIJt7FO2dxiEJERJebtlmFMMAs",
#             "scope": "GOOGLE",
#             "types": [
#                 "casino",
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1448,
#             "vicinity": "Lote 25 Urbanizaci\u00f3n, Paracas"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -13.8565715,
#                     "lng": -76.2521865
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -13.85522167010728,
#                         "lng": -76.25083667010728
#                     },
#                     "southwest": {
#                         "lat": -13.85792132989272,
#                         "lng": -76.25353632989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "DoubleTree Resort by Hilton Paracas - Peru",
#             "opening_hours": {
# ...
#             "reference": "ChIJETjs4CXdrAcRDCDM2A1c7gQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 86,
#             "vicinity": "R. Helena Meira Lima, 89 - Tamba\u00fa, Jo\u00e3o Pessoa"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -7.100821,
#                     "lng": -34.8323364
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -7.099416670107278,
#                         "lng": -34.83087807010727
#                     },
#                     "southwest": {
#                         "lat": -7.102116329892722,
#                         "lng": -34.83357772989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hardman Praia Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1004,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111686920233814636655\">Marcus Vinicius Oliveira</a>"
#                     ],
#                     "photo_reference": "ATtYBwKaGqmgATFyjcabRixkgKt5NaRzVwRgGTmpSFHLr6AUb7JDQeMNNzizF5SQo9GUh_C9V6cvOXji7iKHl_0Pz2-q52lQV4jf_YUMRDIzRzbdSbNDXnjrAy6dKazrVFwr4467yizCCde-2I_84oUJOExfT95H_jNIEdvNyfzFvhM0kHYQ",
#                     "width": 1500
#                 }
#             ],
#             "place_id": "ChIJ31s_VRDdrAcRCrfeDECT3MU",
#             "plus_code": {
#                 "compound_code": "V5X9+M3 Mana\u00edra, Jo\u00e3o Pessoa - State of Para\u00edba, Brazil",
#                 "global_code": "6947V5X9+M3"
#             },
#             "rating": 4.3,
#             "reference": "ChIJ31s_VRDdrAcRCrfeDECT3MU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2175,
#             "vicinity": "Av. Jo\u00e3o Maur\u00edcio, 1341 - Mana\u00edra, Jo\u00e3o Pessoa"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -7.1165106,
#                     "lng": -34.823198
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -7.115175920107277,
#                         "lng": -34.82178477010728
#                     },
#                     "southwest": {
#                         "lat": -7.117875579892721,
#                         "lng": -34.82448442989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Nord Luxxor Tamba\u00fa",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109474475207478475395\">Sapucaia Praia Hotel Nord Luxxor Tamba\u00fa</a>"
#                     ],
#                     "photo_reference": "ATtYBwIJfSe552OPkzuP7YycShQHjgx7-amVrVsdQnFFW4GwHo5MmOxh0ElwQFZauq94PA1FfnlKKVvCTSUT3OSxYQ6Va6qP_C0WJYReQb2Y7AhgOml46F7aC63ga5cDMucCX6bSUcjEbW8HXrjnN-dCiPOyY_FXxSsU08J8yQ07_UDCPj-U",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJzyXPcybdrAcRSqGIzQLutJk",
#             "plus_code": {
#                 "compound_code": "V5MG+9P Tamba\u00fa, Jo\u00e3o Pessoa - State of Para\u00edba, Brazil",
#                 "global_code": "6947V5MG+9P"
#             },
#             "rating": 4.6,
#             "reference": "ChIJzyXPcybdrAcRSqGIzQLutJk",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1120,
#             "vicinity": "Av. Alm. Tamandar\u00e9, 740 - Tamba\u00fa, Jo\u00e3o Pessoa"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -7.0651296,
#                     "lng": -34.840172
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -7.063756420107277,
#                         "lng": -34.83879067010728
#                     },
#                     "southwest": {
#                         "lat": -7.066456079892721,
#                         "lng": -34.84149032989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Bessa Beach Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1467,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111282305966113393656\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwLMTF2d-uSvNfi5yYUXCnhryFVhvKaxr_KpP31NDpDtpsRv_8l4R0taF1I3Jbo67bLDWOx2SADocfVZB7-JaIn_3umO0i14FnzFKJQ36DzKb1vdJkdYu7cP7N2IuGGfH_gvaN23NZg-ZAp6IIsjccEZOuFxQnLZ7EfYO2qoiqowozS2",
#                     "width": 2208
#                 }
#             ],
#             "place_id": "ChIJe9nrdMLdrAcRU-SAPl-ijBk",
#             "plus_code": {
#                 "compound_code": "W5M5+WW Bessa, Jo\u00e3o Pessoa - State of Para\u00edba, Brazil",
#                 "global_code": "6947W5M5+WW"
#             },
#             "rating": 4.3,
#             "reference": "ChIJe9nrdMLdrAcRU-SAPl-ijBk",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1782,
#             "vicinity": "Av. Arthur Monteiro de Paiva, 1066 - Bessa, Jo\u00e3o Pessoa"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -7.1191246,
#                     "lng": -34.8278525
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -7.117890970107277,
#                         "lng": -34.82650242010728
#                     },
#                     "southwest": {
#                         "lat": -7.120590629892721,
#                         "lng": -34.82920207989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Village Premium",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1968,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109677700050370727419\">Eduardo Santos</a>"
#                     ],
#                     "photo_reference": "ATtYBwIEE0HAiEjI3LkYNHwOdiD84eMbJy4NxNpXTCmqob56FCqITD54D4Go46vjolDaxp1lz3wnuNUP5bOE4_9HLEblp7CQVOuELbvrQbD-4gMnDki_if8ldDzcIuPqewhKXS2HbG3CNzsin8iqIXjHPhm9nOFQN0NLrWtZIQGtg0_MHV_S",
#                     "width": 2624
#                 }
#             ],
#             "place_id": "ChIJF4lXsS_drAcRmcmwRX-tSz0",
#             "plus_code": {
#                 "compound_code": "V5JC+9V Tamba\u00fa, Jo\u00e3o Pessoa - State of Para\u00edba, Brazil",
#                 "global_code": "6947V5JC+9V"
#             },
#             "rating": 4.5,
#             "reference": "ChIJF4lXsS_drAcRmcmwRX-tSz0",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1247,
#             "vicinity": "Av. Pres. Epit\u00e1cio Pessoa, 4851 - Tamba\u00fa, Jo\u00e3o Pessoa"
#         }
#     ],
#     "status": "OK"
# }
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 8.044847899999999,
#                     "lng": -6.1887288
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 8.04620292989272,
#                         "lng": -6.187273320107278
#                     },
#                     "southwest": {
#                         "lat": 8.043503270107276,
#                         "lng": -6.189972979892722
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Cajoux",
#             "photos": [
#                 {
#                     "height": 4096,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111974574438797305580\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwILLf7Ainq6VzJfGnTeivg-qby6nkh2GNTTJsewnOgQUa-H3zsznjLRQBN2RDnSlE6bqZLCxrnV3A6TeZjocVaexriBStWBxRSUId_2mKnGhC6_2sZBvpbmB2ziyTdwh13rKIBeGzWSFlgqXNfvFBAMrmzt9QMN-6K-0vdDw1CTKhUl",
#                     "width": 2304
#                 }
#             ],
#             "place_id": "ChIJvXl94-RHtw8RCFWomrXP5f0",
#             "plus_code": {
#                 "compound_code": "2RV6+WG Mankono, C\u00f4te d\u2019Ivoire",
#                 "global_code": "6CWM2RV6+WG"
#             },
#             "rating": 3.2,
#             "reference": "ChIJvXl94-RHtw8RCFWomrXP5f0",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 13,
#             "vicinity": "Quartier Bechet R\u00e9sidentiel"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 8.3249553,
#                     "lng": -6.1068538
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 8.32689552989272,
#                         "lng": -6.105692320107278
#                     },
#                     "southwest": {
#                         "lat": 8.324195870107276,
#                         "lng": -6.108391979892722
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "H\u00f4tel 1 de Tomono",
#             "photos": [
#                 {
#                     "height": 1068,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102041579454653167381\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwIV5JfX7itp8Tk-YOU2WBRDPhynR3K-D0tOBB5BOwqEZn6B83nF-tN_9L5CAdZFlr0nrmlN0kdCdp-IsmApNBIYolViqqri7_H7BAxG2I8Z2OGrrM6b9qW-1BAzqWvRwR_DD597zdbHVI0JIXBxZ8hXP7PfSZ328daXUT3Lcqk-inU",
#                     "width": 712
#                 }
#             ],
#             "place_id": "ChIJMT_Qsksitw8Rl89Gx4kD_9o",
#             "plus_code": {
#                 "compound_code": "8VFV+X7 Tomono, C\u00f4te d\u2019Ivoire",
#                 "global_code": "6CWM8VFV+X7"
#             },
#             "rating": 2.9,
#             "reference": "ChIJMT_Qsksitw8Rl89Gx4kD_9o",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 10,
#             "vicinity": "Tomono"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 8.4707905,
#                     "lng": -6.6072813
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 8.472168829892722,
#                         "lng": -6.605255850000001
#                     },
#                     "southwest": {
#                         "lat": 8.469469170107278,
#                         "lng": -6.607956450000001
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "name": "Hotel Du Bonheur De Kani",
#             "photos": [
#                 {
#                     "height": 2368,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106039433561040852452\">Fal\u00e9 Jean luc</a>"
#                     ],
#                     "photo_reference": "ATtYBwJwfZ-DQ_tSr-RgHlzLbW2lL0vG0DN_04ZhqHj5mgZo7lb7wHEVM3bCANDsbOwAkb_ALfQFdAMKEdgMg3YVXLpH04bzg4h8lTgM18yJ7Gmg8G3GtSjzRMseH0f7iZWyQp6LOJzoTo3TL-Gz9cKq_KSp2lU36RhOKKV0eeTBf4BF3IrF",
#                     "width": 4160
#                 }
#             ],
#             "place_id": "ChIJ1_noovInsQ8RM0niOF7HilI",
#             "plus_code": {
#                 "compound_code": "F9CV+83 Kani, C\u00f4te d\u2019Ivoire",
#                 "global_code": "6CWMF9CV+83"
#             },
#             "rating": 2.8,
#             "reference": "ChIJ1_noovInsQ8RM0niOF7HilI",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 17,
#             "vicinity": "Kani"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 8.0491019,
#                     "lng": -6.189301599999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 8.050544279892723,
#                         "lng": -6.187957320107278
#                     },
#                     "southwest": {
#                         "lat": 8.047844620107279,
#                         "lng": -6.190656979892721
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "name": "\u00c9den Park",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2448,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109090928848853886903\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwLWx0jWhBvUMClfq32pW3ZWiZCuZ6lJd3WSLw3caKm4_PYMONEsqjGqZwXrEdl65XscU3UCVjaqiKyC8BREQvf20U011wef2Lt_nk57E0dkqf9Bz1Vn2xYNlI58YEwKBs5-Ww8f7EF4gB6raev2BXLvgmSiIpB6raUMWRGnL9yYMbjT",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJH8KEBwRHtw8RIRlPROyFpXQ",
#             "plus_code": {
#                 "compound_code": "2RX6+J7 Mankono, C\u00f4te d\u2019Ivoire",
#                 "global_code": "6CWM2RX6+J7"
#             },
#             "price_level": 2,
#             "rating": 4.1,
#             "reference": "ChIJH8KEBwRHtw8RIRlPROyFpXQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 21,
#             "vicinity": "Mankono"
#         }
#     ],
#     "status": "OK"
# }

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{city}</dd>
<dt>Country</dt><dd>{country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["lat", "lon"]]

# %%
# Add marker layer ontop of heat map
markers = gmaps.marker_layer(locations,
    info_box_content=[f"Hotel loc: {rate}" for rate in hotel_info])

fig.add_layer(markers)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
